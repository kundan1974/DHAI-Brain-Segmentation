# %% [markdown]
# # Setup and Imports

# %%
import os
import json
import numpy as np
import nibabel as nib # This library deals with medical images - nifty images
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader, random_split
from torchvision.transforms import functional as TF
from torch.utils.tensorboard import SummaryWriter
import matplotlib.pyplot as plt
import pandas as pd
from datetime import datetime
import random
import time

# %% [markdown]
# # Dataset Class
#
# ### This class is a custom dataset loader for PyTorch that:
# - Reads MRI brain scans (and tumor segmentations) from .nii.gz files (from the BraTS dataset),
# - Applies preprocessing like cropping, normalizing, and flipping,
# - Converts the 3D MRI data into tensors (PyTorch’s format) so they can be used to train a neural network (U-Net in your case).

# %%
class BraTSDataset(Dataset):
    def __init__(self, data_path, crop_dim=(128, 128, 128), number_output_classes=3, randomize=False):
        """
            data_path: Folder where your dataset lives.
        	crop_dim: Size of the 3D patch extracted from the full MRI scan (like zooming into a 128×128×128 box).
        	number_output_classes: How many types of tumor regions you want to segment.
        	randomize: If True, applies random flipping/cropping (used to “augment” your dataset to make your model more robust).
        """
        self.data_path = data_path
        self.crop_dim = crop_dim
        self.randomize = randomize
        self.number_output_classes = number_output_classes
        self._load_metadata()

    def _load_metadata(self):
        """
        	This loads a dataset.json file which contains paths to all MRI and mask files.
        	It stores:
            	self.input_channels: e.g., FLAIR, T1, T2…
            	self.output_channels: e.g., edema, enhancing tumor, etc.
            	self.filenames: pairs of image and corresponding mask file paths.
        """
        with open(os.path.join(self.data_path, "dataset.json"), 'r') as f:
            metadata = json.load(f)

        self.input_channels = metadata["modality"]
        self.output_channels = metadata["labels"]
        self.filenames = [
            (os.path.join(self.data_path, entry["image"]), os.path.join(self.data_path, entry["label"]))
            for entry in metadata["training"]
        ]

    def __len__(self):
        """
        This allows PyTorch to know how many samples the dataset has.
        """
        return len(self.filenames)

    def __getitem__(self, idx):
        """
        This method is called when PyTorch wants the idx-th MRI scan.
        """
        img_path, msk_path = self.filenames[idx]
        
        # img = np.array(nib.load(img_path).dataobj)[..., 0]  # Loads the FLAIR MRI scan (3D data) and selects the first channel.
        img = nib.load(img_path).get_fdata(dtype=np.float32)[..., 0]

        img = np.rot90(img) # Rotates it (to match visual orientation).
        img = img[..., np.newaxis]  # adds a “channel” dimension. -> (D, H, W, 1)

        # Loads the tumor mask (label data).
        # msk = np.array(nib.load(msk_path).dataobj)
        msk = nib.load(msk_path).get_fdata(dtype=np.float32)

        msk = np.rot90(msk)
    
        if self.number_output_classes == 1:
            msk = (msk > 0).astype(np.float32)[..., None]  # shape: (D, H, W, 1)
        else:
            # Converts a single tumor map into multiple binary channels:
        	# Channel 0: everything marked as class 0 (e.g., edema)
        	# Channel 1: class 1 (e.g., non-enhancing tumor)
        	# Channel 2: class 2 (e.g., enhancing tumor)
            msk_temp = np.zeros((*msk.shape, self.number_output_classes), dtype=np.float32)
            for channel in range(self.number_output_classes):
                msk_temp[..., channel] = (msk == channel).astype(np.float32)
            msk = msk_temp
    
        # Extracts a 128×128×128 region around the center (or nearby, if random cropping is on).
        img, msk = self._crop(img, msk)
        # Makes the pixel intensities centered around zero with standard deviation of 1. Helps the model learn better.
        img = self._z_normalize(img)
        # Random flipping (left-right or up-down) to introduce variation.
        if self.randomize:
            img, msk = self._augment(img, msk)

        # Converts image from (D, H, W, C) to (C, D, H, W) as expected by PyTorch.
        img = torch.from_numpy(img.transpose(3, 0, 1, 2).copy()).float() # (C, D, H, W)
        msk = torch.from_numpy(msk.transpose(3, 0, 1, 2).copy()).float()
    
        return img, msk

    def _z_normalize(self, img):
        for c in range(img.shape[-1]):
            channel = img[..., c]
            img[..., c] = (channel - np.mean(channel)) / (np.std(channel) + 1e-8)
        return img

    def _crop(self, img, msk):
        slices = []
        for i in range(3):
            crop_len = self.crop_dim[i]
            start = (img.shape[i] - crop_len) // 2
            offset = int(start * 0.2)
            if self.randomize and offset > 0:
                start += np.random.randint(-offset, offset)
                start = max(0, min(start, img.shape[i] - crop_len))
            slices.append(slice(start, start + crop_len))
        img = img[slices[0], slices[1], slices[2], :]
        msk = msk[slices[0], slices[1], slices[2], :]
        return img, msk

    # def _augment(self, img, msk):
    #     if np.random.rand() > 0.5:
    #         axis = random.choice([0, 1, 2])
    #         img = np.flip(img, axis=axis).copy()
    #         msk = np.flip(msk, axis=axis).copy()
    #     return img, msk

    def _augment(self, img, msk):
        if np.random.rand() > 0.5:
            axis = random.choice([0, 1, 2])
            img = np.flip(img, axis=axis).copy()
            msk = np.flip(msk, axis=axis).copy()
        if np.random.rand() > 0.5:
            img += np.random.normal(0, 0.1, img.shape).astype(np.float32)  # Gaussian noise
        return img, msk

# %% [markdown]
# # Creatting Data loaders

# %%
# dataset = BraTSDataset(data_path="data_brainMRI_Segmentation/",
#                        crop_dim=(128, 128, 128), number_output_classes=3, randomize=True)

# %%
# Load dataset once (no augmentation)
full_dataset = BraTSDataset(data_path="data_brainMRI_Segmentation/",
                            crop_dim=(128, 128, 128),
                            number_output_classes=3,
                            randomize=False)

# Compute split sizes
train_len = int(0.8 * len(full_dataset))
val_len = int(0.1 * len(full_dataset))
test_len = len(full_dataset) - train_len - val_len

# Reproducible split
train_idx, val_idx, test_idx = torch.utils.data.random_split(
    range(len(full_dataset)),
    [train_len, val_len, test_len],
    generator=torch.Generator().manual_seed(42)
)

# Rebuild actual datasets with correct augmentation settings
train_ds = torch.utils.data.Subset(
    BraTSDataset("data_brainMRI_Segmentation/", crop_dim=(128, 128, 128), number_output_classes=3, randomize=True),
    train_idx
)

val_ds = torch.utils.data.Subset(
    BraTSDataset("data_brainMRI_Segmentation/", crop_dim=(128, 128, 128), number_output_classes=3, randomize=False),
    val_idx
)

test_ds = torch.utils.data.Subset(
    BraTSDataset("data_brainMRI_Segmentation/", crop_dim=(128, 128, 128), number_output_classes=3, randomize=False),
    test_idx
)

# Dataloaders
train_dl = DataLoader(train_ds, batch_size=8, shuffle=True)
val_dl = DataLoader(val_ds, batch_size=4)
test_dl = DataLoader(test_ds, batch_size=1)

# %% [markdown]
# # Visualizing Samples

# %%
import matplotlib.pyplot as plt
import random

def show_multiple_random_samples(train_ds, mask_channel=1, num_samples=4):
    fig, axs = plt.subplots(num_samples, 2, figsize=(10, 3 * num_samples))

    for i in range(num_samples):
        idx = random.randint(0, len(train_ds) - 1)
        img, msk = train_ds[idx]

        img_np = img[0].numpy()  # FLAIR image (D, H, W)
        msk_np = msk[mask_channel].numpy()  # Mask for given channel

        slice_idx = random.randint(0, img_np.shape[0] - 1)

        axs[i, 0].imshow(img_np[slice_idx], cmap="gray")
        axs[i, 0].set_title(f"MRI (idx={idx}, slice={slice_idx})")
        axs[i, 0].axis("off")

        axs[i, 1].imshow(msk_np[slice_idx], cmap="Reds", alpha=0.7)
        axs[i, 1].set_title(f"Mask (channel={mask_channel})")
        axs[i, 1].axis("off")

    plt.tight_layout()
    plt.show()

# 🔁 Use this to see 4 random samples with FLAIR and tumor mask
show_multiple_random_samples(train_ds, mask_channel=0)

# %% [markdown]
# # 3D U-Net Model

# %%
class ConvBlock(nn.Module):
    def __init__(self, in_ch, out_ch):
        super().__init__()
        self.block = nn.Sequential(
            nn.Conv3d(in_ch, out_ch, 3, padding=1),
            nn.BatchNorm3d(out_ch),
            nn.ReLU(inplace=True),
            nn.Conv3d(out_ch, out_ch, 3, padding=1),
            nn.BatchNorm3d(out_ch),
            nn.ReLU(inplace=True)
        )

    def forward(self, x):
        return self.block(x)

class UNet3D(nn.Module):
    def __init__(self, in_channels, out_channels, base_ch=8):
        super().__init__()
        self.enc1 = ConvBlock(in_channels, base_ch)
        self.enc2 = ConvBlock(base_ch, base_ch*2)
        self.enc3 = ConvBlock(base_ch*2, base_ch*4)
        self.enc4 = ConvBlock(base_ch*4, base_ch*8)
        self.bottleneck = ConvBlock(base_ch*8, base_ch*16)

        self.up4 = nn.ConvTranspose3d(base_ch*16, base_ch*8, 2, stride=2)
        self.dec4 = ConvBlock(base_ch*16, base_ch*8)
        self.up3 = nn.ConvTranspose3d(base_ch*8, base_ch*4, 2, stride=2)
        self.dec3 = ConvBlock(base_ch*8, base_ch*4)
        self.up2 = nn.ConvTranspose3d(base_ch*4, base_ch*2, 2, stride=2)
        self.dec2 = ConvBlock(base_ch*4, base_ch*2)
        self.up1 = nn.ConvTranspose3d(base_ch*2, base_ch, 2, stride=2)
        self.dec1 = ConvBlock(base_ch*2, base_ch)

        self.out_conv = nn.Conv3d(base_ch, out_channels, kernel_size=1)
        self.final_activation = nn.Sigmoid()

    def forward(self, x):
        e1 = self.enc1(x)
        e2 = self.enc2(F.max_pool3d(e1, 2))
        e3 = self.enc3(F.max_pool3d(e2, 2))
        e4 = self.enc4(F.max_pool3d(e3, 2))
        b = self.bottleneck(F.max_pool3d(e4, 2))

        d4 = self.dec4(torch.cat([self.up4(b), e4], dim=1))
        d3 = self.dec3(torch.cat([self.up3(d4), e3], dim=1))
        d2 = self.dec2(torch.cat([self.up2(d3), e2], dim=1))
        d1 = self.dec1(torch.cat([self.up1(d2), e1], dim=1))

        return self.final_activation(self.out_conv(d1))

# %% [markdown]
# # Dice Loss

# %%
def dice_loss(pred, target, smooth=1e-5):
    pred = pred.contiguous()
    target = target.contiguous()
    intersection = (pred * target).sum(dim=(2, 3, 4))
    union = pred.sum(dim=(2, 3, 4)) + target.sum(dim=(2, 3, 4))
    dice = (2. * intersection + smooth) / (union + smooth)
    return 1 - dice.mean()

def combined_loss(pred, target):
    bce = F.binary_cross_entropy(pred, target)
    dsc = dice_loss(pred, target)
    return 0.5 * bce + 0.5 * dsc

# %%
class EarlyStopping:
    def __init__(self, patience=20, min_delta=0.001):
        """
        Stops training if the validation loss doesn't improve after 'patience' epochs.
        """
        self.patience = patience
        self.min_delta = min_delta
        self.counter = 0
        self.best_loss = None
        self.early_stop = False

    def __call__(self, val_loss):
        if self.best_loss is None:
            self.best_loss = val_loss
        elif val_loss > self.best_loss - self.min_delta:
            self.counter += 1
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_loss = val_loss
            self.counter = 0

# %%
def log_prediction(writer, model, val_dl, epoch, device):
    model.eval()
    with torch.no_grad():
        # Get one random batch
        val_batch = next(iter(val_dl))
        img, msk = val_batch
        img, msk = img.to(device), msk.to(device)

        pred = model(img)

        # First sample in batch
        img = img[0].cpu().numpy()     # (C, D, H, W)
        msk = msk[0].cpu().numpy()     # (C, D, H, W)
        pred = pred[0].cpu().numpy()   # (C, D, H, W)

        slice_idx = img.shape[1] // 2

        # Normalize MRI slice
        mri_slice = img[0, slice_idx]
        mri_slice = (mri_slice - mri_slice.min()) / (mri_slice.max() - mri_slice.min() + 1e-8)
        mri_rgb = np.stack([mri_slice]*3, axis=0)

        panels = [mri_rgb]  # start with MRI

        for ch in range(3):  # for each tumor class
            gt = msk[ch, slice_idx]
            pr = pred[ch, slice_idx]

            gt = (gt - gt.min()) / (gt.max() - gt.min() + 1e-8)
            pr = (pr - pr.min()) / (pr.max() - pr.min() + 1e-8)

            gt_rgb = np.stack([gt]*3, axis=0)
            pr_rgb = np.stack([pr]*3, axis=0)

            panels.extend([gt_rgb, pr_rgb])

        # Concatenate horizontally: [3, H, W_total]
        concat = np.concatenate(panels, axis=2)

        writer.add_image("MRI_GT_Pred_All_Classes", concat, global_step=epoch)

# %%
def log_predictions_across_epochs(writer, model, val_ds, fixed_indices, epoch, device):
    model.eval()
    with torch.no_grad():
        for idx in fixed_indices:
            img, msk = val_ds[idx]
            img = img.unsqueeze(0).to(device)  # Add batch dimension
            msk = msk.numpy()

            pred = model(img).squeeze(0).cpu().numpy()
            img = img.squeeze(0).cpu().numpy()

            slice_idx = img.shape[1] // 2  # middle depth slice
            mri_slice = img[0, slice_idx]
            mri_slice = (mri_slice - mri_slice.min()) / (mri_slice.max() - mri_slice.min() + 1e-8)
            mri_rgb = np.stack([mri_slice]*3, axis=0)

            panels = [mri_rgb]
            for ch in range(3):
                gt = msk[ch, slice_idx]
                pr = pred[ch, slice_idx]

                gt = (gt - gt.min()) / (gt.max() - gt.min() + 1e-8)
                pr = (pr - pr.min()) / (pr.max() - pr.min() + 1e-8)

                gt_rgb = np.stack([gt]*3, axis=0)
                pr_rgb = np.stack([pr]*3, axis=0)

                panels.extend([gt_rgb, pr_rgb])

            concat = np.concatenate(panels, axis=2)

            tag = f"Case_{idx}_Epoch_{epoch+1}"
            # writer.add_image(tag, concat, global_step=epoch)
            writer.add_image("MRI_GT_Pred_All_Classes", concat, global_step=epoch)

# %%
def compute_dice_score(pred, target, smooth=1e-5):
    pred = pred.contiguous()
    target = target.contiguous()
    intersection = (pred * target).sum(dim=(2, 3, 4))
    union = pred.sum(dim=(2, 3, 4)) + target.sum(dim=(2, 3, 4))
    dice = (2. * intersection + smooth) / (union + smooth)
    return dice.mean().item()

# %%
def compute_per_class_dice(pred, target, smooth=1e-5):
    C = pred.shape[1]  # number of classes
    scores = []
    for c in range(C):
        p = pred[:, c]
        t = target[:, c]
        intersection = (p * t).sum(dim=(1, 2, 3))
        union = p.sum(dim=(1, 2, 3)) + t.sum(dim=(1, 2, 3))
        dice = (2. * intersection + smooth) / (union + smooth)
        scores.append(dice.mean().item())
    return scores

# %% [markdown]
# # Training Loop

# %%
# if torch.backends.mps.is_available():
#     device = torch.device("mps")
# elif torch.cuda.is_available():
#     device = torch.device("cuda")
# else:
#     device = torch.device("cpu")

# print(f"Using device: {device}")

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
fixed_val_examples = random.sample(range(len(val_ds)), 5)
train_loss_log = []
val_loss_log = []

best_val_loss = float('inf')
best_model_path = "best_3d_unet_model02.pth"
early_stopper = EarlyStopping(patience=30, min_delta=0.0005)


# model = UNet3D(in_channels=1, out_channels=3, base_ch=8).to(device)
model = UNet3D(in_channels=1, out_channels=3, base_ch=32)
model = nn.DataParallel(model)
model = model.to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

writer = SummaryWriter(log_dir=f"runs/3d_unet_{datetime.now().strftime('%Y%m%d-%H%M%S')}")
num_epochs = 1000
epoch = 0

while epoch < num_epochs:
    start_time = time.time()
    model.train()
    running_loss = 0.0

    print(f"\nEpoch {epoch+1}/{num_epochs}")
    
    for batch_idx, (img, msk) in enumerate(train_dl):
        img, msk = img.to(device), msk.to(device)

        pred = model(img)
        # loss = dice_loss(pred, msk)
        loss = combined_loss(pred, msk)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

        # 🔄 Print status every few batches (or every batch if you want)
        if (batch_idx + 1) % 1 == 0:
            print(f"  Batch {batch_idx+1}/{len(train_dl)} - Loss: {loss.item():.4f}")
            # Flush immediately
            import sys
            sys.stdout.flush()

    avg_loss = running_loss / len(train_dl)
    writer.add_scalar("Loss/train", avg_loss, epoch)

    # Validation
    model.eval()
    val_loss = 0.0
    dice_score_epoch = 0.0
    with torch.no_grad():
        for img, msk in val_dl:
            img, msk = img.to(device), msk.to(device)
            pred = model(img)
            val_loss += dice_loss(pred, msk).item()
            dice_score_epoch += compute_dice_score(pred, msk)

            per_class_scores = compute_per_class_dice(pred, msk)
            for i, score in enumerate(per_class_scores):
                writer.add_scalar(f"Dice_class_{i}/val", score, epoch)
            

    avg_val_loss = val_loss / len(val_dl)
    avg_dice_score = dice_score_epoch / len(val_dl)
    writer.add_scalar("Loss/val", avg_val_loss, epoch)
    writer.add_scalar("Dice/val", avg_dice_score, epoch)
    print(f"Epoch {epoch+1} Completed ✅ | Train Loss: {avg_loss:.4f} | Val Loss: {avg_val_loss:.4f}")
    train_loss_log.append({"epoch": epoch + 1, "loss": avg_loss})
    val_loss_log.append({"epoch": epoch + 1, "loss": avg_val_loss})

    # Save best model
    if avg_val_loss < best_val_loss:
        best_val_loss = avg_val_loss
        torch.save(model.state_dict(), best_model_path)
        print(f"✅ Saved best model at epoch {epoch+1} with val_loss {avg_val_loss:.4f}")

    # Early stopping
    early_stopper(avg_val_loss)
    if early_stopper.early_stop:
        print(f"🛑 Early stopping at epoch {epoch+1}")
        break
    
    # log_prediction(writer, model, val_dl, epoch, device)
    log_predictions_across_epochs(writer, model, val_ds, fixed_val_examples, epoch, device)
    epoch_time = time.time() - start_time
    writer.add_scalar("Time/epoch_duration_sec", epoch_time, epoch)
    epoch += 1

torch.save(model.state_dict(), "3d_unet_decathlon02.pth")
pd.DataFrame(train_loss_log).to_csv("train_loss.csv", index=False)
pd.DataFrame(val_loss_log).to_csv("val_loss.csv", index=False)
# Out:
# Epoch 1/1000
#   Batch 1/49 - Loss: 0.6770
#   Batch 2/49 - Loss: 0.6562
#   Batch 3/49 - Loss: 0.6392
#   Batch 4/49 - Loss: 0.6198
#   Batch 5/49 - Loss: 0.6054
#   Batch 6/49 - Loss: 0.5973
#   Batch 7/49 - Loss: 0.5870
#   Batch 8/49 - Loss: 0.5875
#   Batch 9/49 - Loss: 0.5823
#   Batch 10/49 - Loss: 0.5786
#   Batch 11/49 - Loss: 0.5733
#   Batch 12/49 - Loss: 0.5655
#   Batch 13/49 - Loss: 0.5737
#   Batch 14/49 - Loss: 0.5693
#   Batch 15/49 - Loss: 0.5657
#   Batch 16/49 - Loss: 0.5682
#   Batch 17/49 - Loss: 0.5587
#   Batch 18/49 - Loss: 0.5548
#   Batch 19/49 - Loss: 0.5569
#   Batch 20/49 - Loss: 0.5502
#   Batch 21/49 - Loss: 0.5426
#   Batch 22/49 - Loss: 0.5417
#   Batch 23/49 - Loss: 0.5435
#   Batch 24/49 - Loss: 0.5443
#   Batch 25/49 - Loss: 0.5337
#   Batch 26/49 - Loss: 0.5313
#   Batch 27/49 - Loss: 0.5293
#   Batch 28/49 - Loss: 0.5258
#   Batch 29/49 - Loss: 0.5217
#   Batch 30/49 - Loss: 0.5298
#   Batch 31/49 - Loss: 0.5170
#   Batch 32/49 - Loss: 0.5180
#   Batch 33/49 - Loss: 0.5055
#   Batch 34/49 - Loss: 0.5178
#   Batch 35/49 - Loss: 0.5189
#   Batch 36/49 - Loss: 0.5111
#   Batch 37/49 - Loss: 0.5055
#   Batch 38/49 - Loss: 0.5064
#   Batch 39/49 - Loss: 0.4939
#   Batch 40/49 - Loss: 0.4837
#   Batch 41/49 - Loss: 0.5049
#   Batch 42/49 - Loss: 0.5021
#   Batch 43/49 - Loss: 0.4993
#   Batch 44/49 - Loss: 0.4858
#   Batch 45/49 - Loss: 0.4915
#   Batch 46/49 - Loss: 0.4914
#   Batch 47/49 - Loss: 0.4786
#   Batch 48/49 - Loss: 0.4814
#   Batch 49/49 - Loss: 0.4844
# Epoch 1 Completed ✅ | Train Loss: 0.5430 | Val Loss: 0.6781
# ✅ Saved best model at epoch 1 with val_loss 0.6781
#
# Epoch 2/1000
#   Batch 1/49 - Loss: 0.4814
#   Batch 2/49 - Loss: 0.4868
#   Batch 3/49 - Loss: 0.4768
#   Batch 4/49 - Loss: 0.4793
#   Batch 5/49 - Loss: 0.4587
#   Batch 6/49 - Loss: 0.4498
#   Batch 7/49 - Loss: 0.4623
#   Batch 8/49 - Loss: 0.4745
#   Batch 9/49 - Loss: 0.4589
#   Batch 10/49 - Loss: 0.4543
#   Batch 11/49 - Loss: 0.4538
#   Batch 12/49 - Loss: 0.4521
#   Batch 13/49 - Loss: 0.4547
#   Batch 14/49 - Loss: 0.4469
#   Batch 15/49 - Loss: 0.4453
#   Batch 16/49 - Loss: 0.4403
#   Batch 17/49 - Loss: 0.4460
#   Batch 18/49 - Loss: 0.4324
#   Batch 19/49 - Loss: 0.4305
#   Batch 20/49 - Loss: 0.4356
#   Batch 21/49 - Loss: 0.4373
#   Batch 22/49 - Loss: 0.4300
#   Batch 23/49 - Loss: 0.4316
#   Batch 24/49 - Loss: 0.4369
#   Batch 25/49 - Loss: 0.4328
#   Batch 26/49 - Loss: 0.4196
#   Batch 27/49 - Loss: 0.4261
#   Batch 28/49 - Loss: 0.4305
#   Batch 29/49 - Loss: 0.4175
#   Batch 30/49 - Loss: 0.4193
#   Batch 31/49 - Loss: 0.4317
#   Batch 32/49 - Loss: 0.4087
#   Batch 33/49 - Loss: 0.4123
#   Batch 34/49 - Loss: 0.4204
#   Batch 35/49 - Loss: 0.4043
#   Batch 36/49 - Loss: 0.4045
#   Batch 37/49 - Loss: 0.3999
#   Batch 38/49 - Loss: 0.4128
#   Batch 39/49 - Loss: 0.3967
#   Batch 40/49 - Loss: 0.4162
#   Batch 41/49 - Loss: 0.4006
#   Batch 42/49 - Loss: 0.4019
#   Batch 43/49 - Loss: 0.4087
#   Batch 44/49 - Loss: 0.4002
#   Batch 45/49 - Loss: 0.3909
#   Batch 46/49 - Loss: 0.3828
#   Batch 47/49 - Loss: 0.3908
#   Batch 48/49 - Loss: 0.3798
#   Batch 49/49 - Loss: 0.3691
# Epoch 2 Completed ✅ | Train Loss: 0.4293 | Val Loss: 0.5993
# ✅ Saved best model at epoch 2 with val_loss 0.5993
#
# Epoch 3/1000
#   Batch 1/49 - Loss: 0.3908
#   Batch 2/49 - Loss: 0.3860
#   Batch 3/49 - Loss: 0.3792
#   Batch 4/49 - Loss: 0.3859
#   Batch 5/49 - Loss: 0.3766
#   Batch 6/49 - Loss: 0.3775
#   Batch 7/49 - Loss: 0.4008
#   Batch 8/49 - Loss: 0.3710
#   Batch 9/49 - Loss: 0.3777
#   Batch 10/49 - Loss: 0.3648
#   Batch 11/49 - Loss: 0.3770
#   Batch 12/49 - Loss: 0.3534
#   Batch 13/49 - Loss: 0.3659
#   Batch 14/49 - Loss: 0.3533
#   Batch 15/49 - Loss: 0.3613
#   Batch 16/49 - Loss: 0.3466
#   Batch 17/49 - Loss: 0.3688
#   Batch 18/49 - Loss: 0.3440
#   Batch 19/49 - Loss: 0.3553
#   Batch 20/49 - Loss: 0.3611
#   Batch 21/49 - Loss: 0.3555
#   Batch 22/49 - Loss: 0.3571
#   Batch 23/49 - Loss: 0.3582
#   Batch 24/49 - Loss: 0.3556
#   Batch 25/49 - Loss: 0.3455
#   Batch 26/49 - Loss: 0.3443
#   Batch 27/49 - Loss: 0.3551
#   Batch 28/49 - Loss: 0.3450
#   Batch 29/49 - Loss: 0.3776
#   Batch 30/49 - Loss: 0.3515
#   Batch 31/49 - Loss: 0.3444
#   Batch 32/49 - Loss: 0.3404
#   Batch 33/49 - Loss: 0.3432
#   Batch 34/49 - Loss: 0.3641
#   Batch 35/49 - Loss: 0.3426
#   Batch 36/49 - Loss: 0.3297
#   Batch 37/49 - Loss: 0.3469
#   Batch 38/49 - Loss: 0.3323
#   Batch 39/49 - Loss: 0.3476
#   Batch 40/49 - Loss: 0.3351
#   Batch 41/49 - Loss: 0.3288
#   Batch 42/49 - Loss: 0.3201
#   Batch 43/49 - Loss: 0.3301
#   Batch 44/49 - Loss: 0.3224
#   Batch 45/49 - Loss: 0.3307
#   Batch 46/49 - Loss: 0.3281
#   Batch 47/49 - Loss: 0.3124
#   Batch 48/49 - Loss: 0.3324
#   Batch 49/49 - Loss: 0.3191
# Epoch 3 Completed ✅ | Train Loss: 0.3529 | Val Loss: 0.5461
# ✅ Saved best model at epoch 3 with val_loss 0.5461
#
# Epoch 4/1000
#   Batch 1/49 - Loss: 0.3352
#   Batch 2/49 - Loss: 0.3363
#   Batch 3/49 - Loss: 0.3267
#   Batch 4/49 - Loss: 0.3266
#   Batch 5/49 - Loss: 0.2943
#   Batch 6/49 - Loss: 0.3252
#   Batch 7/49 - Loss: 0.3176
#   Batch 8/49 - Loss: 0.3100
#   Batch 9/49 - Loss: 0.3089
#   Batch 10/49 - Loss: 0.3212
#   Batch 11/49 - Loss: 0.2954
#   Batch 12/49 - Loss: 0.3003
#   Batch 13/49 - Loss: 0.2867
#   Batch 14/49 - Loss: 0.3163
#   Batch 15/49 - Loss: 0.3041
#   Batch 16/49 - Loss: 0.3000
#   Batch 17/49 - Loss: 0.2930
#   Batch 18/49 - Loss: 0.3092
#   Batch 19/49 - Loss: 0.3138
#   Batch 20/49 - Loss: 0.2983
#   Batch 21/49 - Loss: 0.3265
#   Batch 22/49 - Loss: 0.3190
#   Batch 23/49 - Loss: 0.3141
#   Batch 24/49 - Loss: 0.3288
#   Batch 25/49 - Loss: 0.2917
#   Batch 26/49 - Loss: 0.3236
#   Batch 27/49 - Loss: 0.3032
#   Batch 28/49 - Loss: 0.3118
#   Batch 29/49 - Loss: 0.2883
#   Batch 30/49 - Loss: 0.3025
#   Batch 31/49 - Loss: 0.2950
#   Batch 32/49 - Loss: 0.2994
#   Batch 33/49 - Loss: 0.2988
#   Batch 34/49 - Loss: 0.3128
#   Batch 35/49 - Loss: 0.2884
#   Batch 36/49 - Loss: 0.3026
#   Batch 37/49 - Loss: 0.3092
#   Batch 38/49 - Loss: 0.2860
#   Batch 39/49 - Loss: 0.2919
#   Batch 40/49 - Loss: 0.3235
#   Batch 41/49 - Loss: 0.3024
#   Batch 42/49 - Loss: 0.2951
#   Batch 43/49 - Loss: 0.3047
#   Batch 44/49 - Loss: 0.2781
#   Batch 45/49 - Loss: 0.2973
#   Batch 46/49 - Loss: 0.2974
#   Batch 47/49 - Loss: 0.2962
#   Batch 48/49 - Loss: 0.2910
#   Batch 49/49 - Loss: 0.2969
# Epoch 4 Completed ✅ | Train Loss: 0.3060 | Val Loss: 0.4981
# ✅ Saved best model at epoch 4 with val_loss 0.4981
#
# Epoch 5/1000
#   Batch 1/49 - Loss: 0.2754
#   Batch 2/49 - Loss: 0.2776
#   Batch 3/49 - Loss: 0.2810
#   Batch 4/49 - Loss: 0.3148
#   Batch 5/49 - Loss: 0.2810
#   Batch 6/49 - Loss: 0.2823
#   Batch 7/49 - Loss: 0.2858
#   Batch 8/49 - Loss: 0.2885
#   Batch 9/49 - Loss: 0.2816
#   Batch 10/49 - Loss: 0.2785
#   Batch 11/49 - Loss: 0.2614
#   Batch 12/49 - Loss: 0.3085
#   Batch 13/49 - Loss: 0.2757
#   Batch 14/49 - Loss: 0.2844
#   Batch 15/49 - Loss: 0.2725
#   Batch 16/49 - Loss: 0.2789
#   Batch 17/49 - Loss: 0.2862
#   Batch 18/49 - Loss: 0.2761
#   Batch 19/49 - Loss: 0.2873
#   Batch 20/49 - Loss: 0.2771
#   Batch 21/49 - Loss: 0.2629
#   Batch 22/49 - Loss: 0.2749
#   Batch 23/49 - Loss: 0.2789
#   Batch 24/49 - Loss: 0.2771
#   Batch 25/49 - Loss: 0.2474
#   Batch 26/49 - Loss: 0.2618
#   Batch 27/49 - Loss: 0.2812
#   Batch 28/49 - Loss: 0.2699
#   Batch 29/49 - Loss: 0.2866
#   Batch 30/49 - Loss: 0.2585
#   Batch 31/49 - Loss: 0.2923
#   Batch 32/49 - Loss: 0.2704
#   Batch 33/49 - Loss: 0.2704
#   Batch 34/49 - Loss: 0.2514
#   Batch 35/49 - Loss: 0.2867
#   Batch 36/49 - Loss: 0.2744
#   Batch 37/49 - Loss: 0.2901
#   Batch 38/49 - Loss: 0.2728
#   Batch 39/49 - Loss: 0.2806
#   Batch 40/49 - Loss: 0.2539
#   Batch 41/49 - Loss: 0.2650
#   Batch 42/49 - Loss: 0.2915
#   Batch 43/49 - Loss: 0.2541
#   Batch 44/49 - Loss: 0.2624
#   Batch 45/49 - Loss: 0.2573
#   Batch 46/49 - Loss: 0.2640
#   Batch 47/49 - Loss: 0.2446
#   Batch 48/49 - Loss: 0.2731
#   Batch 49/49 - Loss: 0.2818
# Epoch 5 Completed ✅ | Train Loss: 0.2753 | Val Loss: 0.4665
# ✅ Saved best model at epoch 5 with val_loss 0.4665
#
# Epoch 6/1000
#   Batch 1/49 - Loss: 0.2757
#   Batch 2/49 - Loss: 0.2630
#   Batch 3/49 - Loss: 0.2559
#   Batch 4/49 - Loss: 0.2798
#   Batch 5/49 - Loss: 0.2460
#   Batch 6/49 - Loss: 0.2445
#   Batch 7/49 - Loss: 0.2641
#   Batch 8/49 - Loss: 0.2810
#   Batch 9/49 - Loss: 0.2575
#   Batch 10/49 - Loss: 0.2514
#   Batch 11/49 - Loss: 0.2490
#   Batch 12/49 - Loss: 0.2773
#   Batch 13/49 - Loss: 0.2498
#   Batch 14/49 - Loss: 0.2704
#   Batch 15/49 - Loss: 0.2869
#   Batch 16/49 - Loss: 0.2515
#   Batch 17/49 - Loss: 0.2539
#   Batch 18/49 - Loss: 0.2843
#   Batch 19/49 - Loss: 0.2692
#   Batch 20/49 - Loss: 0.2747
#   Batch 21/49 - Loss: 0.2584
#   Batch 22/49 - Loss: 0.2748
#   Batch 23/49 - Loss: 0.2684
#   Batch 24/49 - Loss: 0.2434
#   Batch 25/49 - Loss: 0.2659
#   Batch 26/49 - Loss: 0.2580
#   Batch 27/49 - Loss: 0.2660
#   Batch 28/49 - Loss: 0.2551
#   Batch 29/49 - Loss: 0.2750
#   Batch 30/49 - Loss: 0.2700
#   Batch 31/49 - Loss: 0.2478
#   Batch 32/49 - Loss: 0.2584
#   Batch 33/49 - Loss: 0.2364
#   Batch 34/49 - Loss: 0.2633
#   Batch 35/49 - Loss: 0.2574
#   Batch 36/49 - Loss: 0.2506
#   Batch 37/49 - Loss: 0.2513
#   Batch 38/49 - Loss: 0.2435
#   Batch 39/49 - Loss: 0.2364
#   Batch 40/49 - Loss: 0.2281
#   Batch 41/49 - Loss: 0.2433
#   Batch 42/49 - Loss: 0.2522
#   Batch 43/49 - Loss: 0.2341
#   Batch 44/49 - Loss: 0.2546
#   Batch 45/49 - Loss: 0.2451
#   Batch 46/49 - Loss: 0.2592
#   Batch 47/49 - Loss: 0.2374
#   Batch 48/49 - Loss: 0.2475
#   Batch 49/49 - Loss: 0.2256
# Epoch 6 Completed ✅ | Train Loss: 0.2570 | Val Loss: 0.4331
# ✅ Saved best model at epoch 6 with val_loss 0.4331
#
# Epoch 7/1000
#   Batch 1/49 - Loss: 0.2511
#   Batch 2/49 - Loss: 0.2331
#   Batch 3/49 - Loss: 0.2305
#   Batch 4/49 - Loss: 0.2561
#   Batch 5/49 - Loss: 0.2426
#   Batch 6/49 - Loss: 0.2503
#   Batch 7/49 - Loss: 0.2631
#   Batch 8/49 - Loss: 0.2568
#   Batch 9/49 - Loss: 0.2568
#   Batch 10/49 - Loss: 0.2486
#   Batch 11/49 - Loss: 0.2580
#   Batch 12/49 - Loss: 0.2370
#   Batch 13/49 - Loss: 0.2534
#   Batch 14/49 - Loss: 0.2688
#   Batch 15/49 - Loss: 0.2481
#   Batch 16/49 - Loss: 0.2544
#   Batch 17/49 - Loss: 0.2488
#   Batch 18/49 - Loss: 0.2422
#   Batch 19/49 - Loss: 0.2316
#   Batch 20/49 - Loss: 0.2661
#   Batch 21/49 - Loss: 0.2364
#   Batch 22/49 - Loss: 0.2383
#   Batch 23/49 - Loss: 0.2726
#   Batch 24/49 - Loss: 0.2455
#   Batch 25/49 - Loss: 0.2317
#   Batch 26/49 - Loss: 0.2576
#   Batch 27/49 - Loss: 0.2459
#   Batch 28/49 - Loss: 0.2405
#   Batch 29/49 - Loss: 0.2491
#   Batch 30/49 - Loss: 0.2313
#   Batch 31/49 - Loss: 0.2314
#   Batch 32/49 - Loss: 0.2325
#   Batch 33/49 - Loss: 0.2471
#   Batch 34/49 - Loss: 0.2726
#   Batch 35/49 - Loss: 0.2241
#   Batch 36/49 - Loss: 0.2237
#   Batch 37/49 - Loss: 0.2456
#   Batch 38/49 - Loss: 0.2298
#   Batch 39/49 - Loss: 0.2424
#   Batch 40/49 - Loss: 0.2353
#   Batch 41/49 - Loss: 0.2467
#   Batch 42/49 - Loss: 0.2585
#   Batch 43/49 - Loss: 0.2339
#   Batch 44/49 - Loss: 0.2305
#   Batch 45/49 - Loss: 0.2459
#   Batch 46/49 - Loss: 0.2438
#   Batch 47/49 - Loss: 0.2391
#   Batch 48/49 - Loss: 0.2551
#   Batch 49/49 - Loss: 0.2349
# Epoch 7 Completed ✅ | Train Loss: 0.2453 | Val Loss: 0.4625
#
# Epoch 8/1000
#   Batch 1/49 - Loss: 0.2381
#   Batch 2/49 - Loss: 0.2448
#   Batch 3/49 - Loss: 0.2128
#   Batch 4/49 - Loss: 0.2386
#   Batch 5/49 - Loss: 0.2414
#   Batch 6/49 - Loss: 0.2631
#   Batch 7/49 - Loss: 0.2342
#   Batch 8/49 - Loss: 0.2344
#   Batch 9/49 - Loss: 0.2333
#   Batch 10/49 - Loss: 0.2582
#   Batch 11/49 - Loss: 0.2354
#   Batch 12/49 - Loss: 0.2188
#   Batch 13/49 - Loss: 0.2141
#   Batch 14/49 - Loss: 0.2671
#   Batch 15/49 - Loss: 0.2592
#   Batch 16/49 - Loss: 0.2303
#   Batch 17/49 - Loss: 0.2433
#   Batch 18/49 - Loss: 0.2132
#   Batch 19/49 - Loss: 0.2429
#   Batch 20/49 - Loss: 0.2412
#   Batch 21/49 - Loss: 0.2215
#   Batch 22/49 - Loss: 0.2279
#   Batch 23/49 - Loss: 0.2248
#   Batch 24/49 - Loss: 0.2382
#   Batch 25/49 - Loss: 0.2658
#   Batch 26/49 - Loss: 0.2500
#   Batch 27/49 - Loss: 0.2362
#   Batch 28/49 - Loss: 0.2412
#   Batch 29/49 - Loss: 0.2485
#   Batch 30/49 - Loss: 0.2241
#   Batch 31/49 - Loss: 0.2146
#   Batch 32/49 - Loss: 0.2299
#   Batch 33/49 - Loss: 0.2426
#   Batch 34/49 - Loss: 0.2582
#   Batch 35/49 - Loss: 0.2287
#   Batch 36/49 - Loss: 0.2254
#   Batch 37/49 - Loss: 0.2370
#   Batch 38/49 - Loss: 0.2260
#   Batch 39/49 - Loss: 0.2481
#   Batch 40/49 - Loss: 0.2506
#   Batch 41/49 - Loss: 0.2516
#   Batch 42/49 - Loss: 0.2231
#   Batch 43/49 - Loss: 0.2374
#   Batch 44/49 - Loss: 0.2220
#   Batch 45/49 - Loss: 0.2301
#   Batch 46/49 - Loss: 0.2168
#   Batch 47/49 - Loss: 0.2290
#   Batch 48/49 - Loss: 0.2444
#   Batch 49/49 - Loss: 0.2248
# Epoch 8 Completed ✅ | Train Loss: 0.2364 | Val Loss: 0.4200
# ✅ Saved best model at epoch 8 with val_loss 0.4200
#
# Epoch 9/1000
#   Batch 1/49 - Loss: 0.2342
#   Batch 2/49 - Loss: 0.2237
#   Batch 3/49 - Loss: 0.2423
#   Batch 4/49 - Loss: 0.2367
#   Batch 5/49 - Loss: 0.2415
#   Batch 6/49 - Loss: 0.2504
#   Batch 7/49 - Loss: 0.2329
#   Batch 8/49 - Loss: 0.2379
#   Batch 9/49 - Loss: 0.2356
#   Batch 10/49 - Loss: 0.2556
#   Batch 11/49 - Loss: 0.2301
#   Batch 12/49 - Loss: 0.2452
#   Batch 13/49 - Loss: 0.2374
#   Batch 14/49 - Loss: 0.2298
#   Batch 15/49 - Loss: 0.2614
#   Batch 16/49 - Loss: 0.2604
#   Batch 17/49 - Loss: 0.2335
#   Batch 18/49 - Loss: 0.2075
#   Batch 19/49 - Loss: 0.2166
#   Batch 20/49 - Loss: 0.2150
#   Batch 21/49 - Loss: 0.2299
#   Batch 22/49 - Loss: 0.2423
#   Batch 23/49 - Loss: 0.2326
#   Batch 24/49 - Loss: 0.2592
#   Batch 25/49 - Loss: 0.2183
#   Batch 26/49 - Loss: 0.2316
#   Batch 27/49 - Loss: 0.2215
#   Batch 28/49 - Loss: 0.2272
#   Batch 29/49 - Loss: 0.2532
#   Batch 30/49 - Loss: 0.2141
#   Batch 31/49 - Loss: 0.2097
#   Batch 32/49 - Loss: 0.2148
#   Batch 33/49 - Loss: 0.2035
#   Batch 34/49 - Loss: 0.2131
#   Batch 35/49 - Loss: 0.2313
#   Batch 36/49 - Loss: 0.2204
#   Batch 37/49 - Loss: 0.2212
#   Batch 38/49 - Loss: 0.2162
#   Batch 39/49 - Loss: 0.2049
#   Batch 40/49 - Loss: 0.2137
#   Batch 41/49 - Loss: 0.2187
#   Batch 42/49 - Loss: 0.2468
#   Batch 43/49 - Loss: 0.2140
#   Batch 44/49 - Loss: 0.2265
#   Batch 45/49 - Loss: 0.2365
#   Batch 46/49 - Loss: 0.2604
#   Batch 47/49 - Loss: 0.2087
#   Batch 48/49 - Loss: 0.2039
#   Batch 49/49 - Loss: 0.2020
# Epoch 9 Completed ✅ | Train Loss: 0.2291 | Val Loss: 0.3958
# ✅ Saved best model at epoch 9 with val_loss 0.3958
#
# Epoch 10/1000
#   Batch 1/49 - Loss: 0.2330
#   Batch 2/49 - Loss: 0.2419
#   Batch 3/49 - Loss: 0.2210
#   Batch 4/49 - Loss: 0.2252
#   Batch 5/49 - Loss: 0.2122
#   Batch 6/49 - Loss: 0.2501
#   Batch 7/49 - Loss: 0.2416
#   Batch 8/49 - Loss: 0.2255
#   Batch 9/49 - Loss: 0.2316
#   Batch 10/49 - Loss: 0.2167
#   Batch 11/49 - Loss: 0.2223
#   Batch 12/49 - Loss: 0.2417
#   Batch 13/49 - Loss: 0.2167
#   Batch 14/49 - Loss: 0.2030
#   Batch 15/49 - Loss: 0.2207
#   Batch 16/49 - Loss: 0.2291
#   Batch 17/49 - Loss: 0.2213
#   Batch 18/49 - Loss: 0.2204
#   Batch 19/49 - Loss: 0.2604
#   Batch 20/49 - Loss: 0.2358
#   Batch 21/49 - Loss: 0.2115
#   Batch 22/49 - Loss: 0.2267
#   Batch 23/49 - Loss: 0.2206
#   Batch 24/49 - Loss: 0.2170
#   Batch 25/49 - Loss: 0.2230
#   Batch 26/49 - Loss: 0.2162
#   Batch 27/49 - Loss: 0.2190
#   Batch 28/49 - Loss: 0.2314
#   Batch 29/49 - Loss: 0.1949
#   Batch 30/49 - Loss: 0.2580
#   Batch 31/49 - Loss: 0.2570
#   Batch 32/49 - Loss: 0.2232
#   Batch 33/49 - Loss: 0.2232
#   Batch 34/49 - Loss: 0.2169
#   Batch 35/49 - Loss: 0.2374
#   Batch 36/49 - Loss: 0.2144
#   Batch 37/49 - Loss: 0.2440
#   Batch 38/49 - Loss: 0.2358
#   Batch 39/49 - Loss: 0.2232
#   Batch 40/49 - Loss: 0.2366
#   Batch 41/49 - Loss: 0.2167
#   Batch 42/49 - Loss: 0.2297
#   Batch 43/49 - Loss: 0.2470
#   Batch 44/49 - Loss: 0.2248
#   Batch 45/49 - Loss: 0.2466
#   Batch 46/49 - Loss: 0.2109
#   Batch 47/49 - Loss: 0.2202
#   Batch 48/49 - Loss: 0.2293
#   Batch 49/49 - Loss: 0.2135
# Epoch 10 Completed ✅ | Train Loss: 0.2273 | Val Loss: 0.3990
#
# Epoch 11/1000
#   Batch 1/49 - Loss: 0.2400
#   Batch 2/49 - Loss: 0.2224
#   Batch 3/49 - Loss: 0.2559
#   Batch 4/49 - Loss: 0.2057
#   Batch 5/49 - Loss: 0.2221
#   Batch 6/49 - Loss: 0.2250
#   Batch 7/49 - Loss: 0.2142
#   Batch 8/49 - Loss: 0.2176
#   Batch 9/49 - Loss: 0.2164
#   Batch 10/49 - Loss: 0.2154
#   Batch 11/49 - Loss: 0.1927
#   Batch 12/49 - Loss: 0.2281
#   Batch 13/49 - Loss: 0.2164
#   Batch 14/49 - Loss: 0.2132
#   Batch 15/49 - Loss: 0.2064
#   Batch 16/49 - Loss: 0.2339
#   Batch 17/49 - Loss: 0.2255
#   Batch 18/49 - Loss: 0.2241
#   Batch 19/49 - Loss: 0.2166
#   Batch 20/49 - Loss: 0.2019
#   Batch 21/49 - Loss: 0.2125
#   Batch 22/49 - Loss: 0.2529
#   Batch 23/49 - Loss: 0.2281
#   Batch 24/49 - Loss: 0.2287
#   Batch 25/49 - Loss: 0.2188
#   Batch 26/49 - Loss: 0.2131
#   Batch 27/49 - Loss: 0.2267
#   Batch 28/49 - Loss: 0.2234
#   Batch 29/49 - Loss: 0.2334
#   Batch 30/49 - Loss: 0.2089
#   Batch 31/49 - Loss: 0.2132
#   Batch 32/49 - Loss: 0.2124
#   Batch 33/49 - Loss: 0.2098
#   Batch 34/49 - Loss: 0.2251
#   Batch 35/49 - Loss: 0.2279
#   Batch 36/49 - Loss: 0.2194
#   Batch 37/49 - Loss: 0.2428
#   Batch 38/49 - Loss: 0.1995
#   Batch 39/49 - Loss: 0.2087
#   Batch 40/49 - Loss: 0.2185
#   Batch 41/49 - Loss: 0.2117
#   Batch 42/49 - Loss: 0.2290
#   Batch 43/49 - Loss: 0.2152
#   Batch 44/49 - Loss: 0.2237
#   Batch 45/49 - Loss: 0.2062
#   Batch 46/49 - Loss: 0.2388
#   Batch 47/49 - Loss: 0.2511
#   Batch 48/49 - Loss: 0.2400
#   Batch 49/49 - Loss: 0.2045
# Epoch 11 Completed ✅ | Train Loss: 0.2212 | Val Loss: 0.3842
# ✅ Saved best model at epoch 11 with val_loss 0.3842
#
# Epoch 12/1000
#   Batch 1/49 - Loss: 0.2197
#   Batch 2/49 - Loss: 0.2201
#   Batch 3/49 - Loss: 0.2269
#   Batch 4/49 - Loss: 0.2374
#   Batch 5/49 - Loss: 0.2211
#   Batch 6/49 - Loss: 0.2235
#   Batch 7/49 - Loss: 0.2167
#   Batch 8/49 - Loss: 0.2044
#   Batch 9/49 - Loss: 0.2008
#   Batch 10/49 - Loss: 0.2087
#   Batch 11/49 - Loss: 0.2132
#   Batch 12/49 - Loss: 0.2412
#   Batch 13/49 - Loss: 0.2322
#   Batch 14/49 - Loss: 0.2178
#   Batch 15/49 - Loss: 0.2251
#   Batch 16/49 - Loss: 0.1973
#   Batch 17/49 - Loss: 0.2314
#   Batch 18/49 - Loss: 0.2174
#   Batch 19/49 - Loss: 0.2320
#   Batch 20/49 - Loss: 0.2141
#   Batch 21/49 - Loss: 0.2124
#   Batch 22/49 - Loss: 0.2108
#   Batch 23/49 - Loss: 0.2206
#   Batch 24/49 - Loss: 0.2147
#   Batch 25/49 - Loss: 0.2235
#   Batch 26/49 - Loss: 0.2463
#   Batch 27/49 - Loss: 0.1909
#   Batch 28/49 - Loss: 0.2142
#   Batch 29/49 - Loss: 0.2030
#   Batch 30/49 - Loss: 0.2304
#   Batch 31/49 - Loss: 0.2337
#   Batch 32/49 - Loss: 0.2099
#   Batch 33/49 - Loss: 0.2268
#   Batch 34/49 - Loss: 0.2150
#   Batch 35/49 - Loss: 0.2079
#   Batch 36/49 - Loss: 0.2152
#   Batch 37/49 - Loss: 0.2323
#   Batch 38/49 - Loss: 0.1862
#   Batch 39/49 - Loss: 0.2263
#   Batch 40/49 - Loss: 0.2181
#   Batch 41/49 - Loss: 0.2098
#   Batch 42/49 - Loss: 0.2164
#   Batch 43/49 - Loss: 0.2156
#   Batch 44/49 - Loss: 0.2100
#   Batch 45/49 - Loss: 0.2244
#   Batch 46/49 - Loss: 0.2066
#   Batch 47/49 - Loss: 0.2040
#   Batch 48/49 - Loss: 0.2163
#   Batch 49/49 - Loss: 0.2048
# Epoch 12 Completed ✅ | Train Loss: 0.2173 | Val Loss: 0.3850
#
# Epoch 13/1000
#   Batch 1/49 - Loss: 0.1979
#   Batch 2/49 - Loss: 0.2109
#   Batch 3/49 - Loss: 0.2063
#   Batch 4/49 - Loss: 0.2101
#   Batch 5/49 - Loss: 0.2367
#   Batch 6/49 - Loss: 0.2138
#   Batch 7/49 - Loss: 0.2044
#   Batch 8/49 - Loss: 0.2060
#   Batch 9/49 - Loss: 0.2404
#   Batch 10/49 - Loss: 0.2078
#   Batch 11/49 - Loss: 0.2005
#   Batch 12/49 - Loss: 0.2183
#   Batch 13/49 - Loss: 0.2180
#   Batch 14/49 - Loss: 0.2258
#   Batch 15/49 - Loss: 0.2232
#   Batch 16/49 - Loss: 0.2201
#   Batch 17/49 - Loss: 0.2173
#   Batch 18/49 - Loss: 0.2173
#   Batch 19/49 - Loss: 0.2048
#   Batch 20/49 - Loss: 0.2258
#   Batch 21/49 - Loss: 0.1885
#   Batch 22/49 - Loss: 0.2194
#   Batch 23/49 - Loss: 0.2099
#   Batch 24/49 - Loss: 0.2069
#   Batch 25/49 - Loss: 0.1986
#   Batch 26/49 - Loss: 0.2014
#   Batch 27/49 - Loss: 0.1812
#   Batch 28/49 - Loss: 0.2298
#   Batch 29/49 - Loss: 0.2151
#   Batch 30/49 - Loss: 0.2011
#   Batch 31/49 - Loss: 0.1984
#   Batch 32/49 - Loss: 0.1992
#   Batch 33/49 - Loss: 0.2306
#   Batch 34/49 - Loss: 0.2264
#   Batch 35/49 - Loss: 0.1935
#   Batch 36/49 - Loss: 0.2232
#   Batch 37/49 - Loss: 0.2192
#   Batch 38/49 - Loss: 0.1887
#   Batch 39/49 - Loss: 0.2334
#   Batch 40/49 - Loss: 0.2216
#   Batch 41/49 - Loss: 0.1911
#   Batch 42/49 - Loss: 0.2156
#   Batch 43/49 - Loss: 0.2462
#   Batch 44/49 - Loss: 0.1855
#   Batch 45/49 - Loss: 0.2206
#   Batch 46/49 - Loss: 0.2242
#   Batch 47/49 - Loss: 0.2353
#   Batch 48/49 - Loss: 0.2124
#   Batch 49/49 - Loss: 0.1936
# Epoch 13 Completed ✅ | Train Loss: 0.2126 | Val Loss: 0.3824
# ✅ Saved best model at epoch 13 with val_loss 0.3824
#
# Epoch 14/1000
#   Batch 1/49 - Loss: 0.2160
#   Batch 2/49 - Loss: 0.1920
#   Batch 3/49 - Loss: 0.2007
#   Batch 4/49 - Loss: 0.2015
#   Batch 5/49 - Loss: 0.2097
#   Batch 6/49 - Loss: 0.1842
#   Batch 7/49 - Loss: 0.2363
#   Batch 8/49 - Loss: 0.2247
#   Batch 9/49 - Loss: 0.2287
#   Batch 10/49 - Loss: 0.2297
#   Batch 11/49 - Loss: 0.2115
#   Batch 12/49 - Loss: 0.2274
#   Batch 13/49 - Loss: 0.2158
#   Batch 14/49 - Loss: 0.1937
#   Batch 15/49 - Loss: 0.1982
#   Batch 16/49 - Loss: 0.2053
#   Batch 17/49 - Loss: 0.1906
#   Batch 18/49 - Loss: 0.2388
#   Batch 19/49 - Loss: 0.1970
#   Batch 20/49 - Loss: 0.2059
#   Batch 21/49 - Loss: 0.2303
#   Batch 22/49 - Loss: 0.2067
#   Batch 23/49 - Loss: 0.2077
#   Batch 24/49 - Loss: 0.1909
#   Batch 25/49 - Loss: 0.2072
#   Batch 26/49 - Loss: 0.2058
#   Batch 27/49 - Loss: 0.2028
#   Batch 28/49 - Loss: 0.2143
#   Batch 29/49 - Loss: 0.2472
#   Batch 30/49 - Loss: 0.2300
#   Batch 31/49 - Loss: 0.2147
#   Batch 32/49 - Loss: 0.2125
#   Batch 33/49 - Loss: 0.1854
#   Batch 34/49 - Loss: 0.2127
#   Batch 35/49 - Loss: 0.2219
#   Batch 36/49 - Loss: 0.2003
#   Batch 37/49 - Loss: 0.2282
#   Batch 38/49 - Loss: 0.2232
#   Batch 39/49 - Loss: 0.1973
#   Batch 40/49 - Loss: 0.2025
#   Batch 41/49 - Loss: 0.2132
#   Batch 42/49 - Loss: 0.2053
#   Batch 43/49 - Loss: 0.2363
#   Batch 44/49 - Loss: 0.2063
#   Batch 45/49 - Loss: 0.2060
#   Batch 46/49 - Loss: 0.2115
#   Batch 47/49 - Loss: 0.1984
#   Batch 48/49 - Loss: 0.2214
#   Batch 49/49 - Loss: 0.2425
# Epoch 14 Completed ✅ | Train Loss: 0.2120 | Val Loss: 0.3783
# ✅ Saved best model at epoch 14 with val_loss 0.3783
#
# Epoch 15/1000
#   Batch 1/49 - Loss: 0.2017
#   Batch 2/49 - Loss: 0.1963
#   Batch 3/49 - Loss: 0.2112
#   Batch 4/49 - Loss: 0.2128
#   Batch 5/49 - Loss: 0.2179
#   Batch 6/49 - Loss: 0.2611
#   Batch 7/49 - Loss: 0.2314
#   Batch 8/49 - Loss: 0.2100
#   Batch 9/49 - Loss: 0.2124
#   Batch 10/49 - Loss: 0.1776
#   Batch 11/49 - Loss: 0.2276
#   Batch 12/49 - Loss: 0.2092
#   Batch 13/49 - Loss: 0.1995
#   Batch 14/49 - Loss: 0.1826
#   Batch 15/49 - Loss: 0.2386
#   Batch 16/49 - Loss: 0.2218
#   Batch 17/49 - Loss: 0.2025
#   Batch 18/49 - Loss: 0.1965
#   Batch 19/49 - Loss: 0.2150
#   Batch 20/49 - Loss: 0.1896
#   Batch 21/49 - Loss: 0.2125
#   Batch 22/49 - Loss: 0.2034
#   Batch 23/49 - Loss: 0.2019
#   Batch 24/49 - Loss: 0.2105
#   Batch 25/49 - Loss: 0.1927
#   Batch 26/49 - Loss: 0.2313
#   Batch 27/49 - Loss: 0.2084
#   Batch 28/49 - Loss: 0.2163
#   Batch 29/49 - Loss: 0.2130
#   Batch 30/49 - Loss: 0.2236
#   Batch 31/49 - Loss: 0.2209
#   Batch 32/49 - Loss: 0.1974
#   Batch 33/49 - Loss: 0.2032
#   Batch 34/49 - Loss: 0.1958
#   Batch 35/49 - Loss: 0.2500
#   Batch 36/49 - Loss: 0.2020
#   Batch 37/49 - Loss: 0.1982
#   Batch 38/49 - Loss: 0.1786
#   Batch 39/49 - Loss: 0.2277
#   Batch 40/49 - Loss: 0.2075
#   Batch 41/49 - Loss: 0.2224
#   Batch 42/49 - Loss: 0.2156
#   Batch 43/49 - Loss: 0.2191
#   Batch 44/49 - Loss: 0.2160
#   Batch 45/49 - Loss: 0.1925
#   Batch 46/49 - Loss: 0.2109
#   Batch 47/49 - Loss: 0.2135
#   Batch 48/49 - Loss: 0.2025
#   Batch 49/49 - Loss: 0.2660
# Epoch 15 Completed ✅ | Train Loss: 0.2116 | Val Loss: 0.4041
#
# Epoch 16/1000
#   Batch 1/49 - Loss: 0.2028
#   Batch 2/49 - Loss: 0.1998
#   Batch 3/49 - Loss: 0.2088
#   Batch 4/49 - Loss: 0.2197
#   Batch 5/49 - Loss: 0.2274
#   Batch 6/49 - Loss: 0.2021
#   Batch 7/49 - Loss: 0.2101
#   Batch 8/49 - Loss: 0.2158
#   Batch 9/49 - Loss: 0.2166
#   Batch 10/49 - Loss: 0.2124
#   Batch 11/49 - Loss: 0.1913
#   Batch 12/49 - Loss: 0.2071
#   Batch 13/49 - Loss: 0.1896
#   Batch 14/49 - Loss: 0.2019
#   Batch 15/49 - Loss: 0.2149
#   Batch 16/49 - Loss: 0.1939
#   Batch 17/49 - Loss: 0.2277
#   Batch 18/49 - Loss: 0.1950
#   Batch 19/49 - Loss: 0.1982
#   Batch 20/49 - Loss: 0.2083
#   Batch 21/49 - Loss: 0.1984
#   Batch 22/49 - Loss: 0.1986
#   Batch 23/49 - Loss: 0.1903
#   Batch 24/49 - Loss: 0.2088
#   Batch 25/49 - Loss: 0.2056
#   Batch 26/49 - Loss: 0.1706
#   Batch 27/49 - Loss: 0.2073
#   Batch 28/49 - Loss: 0.2080
#   Batch 29/49 - Loss: 0.2059
#   Batch 30/49 - Loss: 0.1919
#   Batch 31/49 - Loss: 0.1869
#   Batch 32/49 - Loss: 0.2156
#   Batch 33/49 - Loss: 0.2332
#   Batch 34/49 - Loss: 0.1934
#   Batch 35/49 - Loss: 0.2060
#   Batch 36/49 - Loss: 0.2259
#   Batch 37/49 - Loss: 0.1798
#   Batch 38/49 - Loss: 0.2128
#   Batch 39/49 - Loss: 0.2147
#   Batch 40/49 - Loss: 0.1873
#   Batch 41/49 - Loss: 0.1914
#   Batch 42/49 - Loss: 0.2122
#   Batch 43/49 - Loss: 0.2116
#   Batch 44/49 - Loss: 0.2178
#   Batch 45/49 - Loss: 0.2124
#   Batch 46/49 - Loss: 0.1863
#   Batch 47/49 - Loss: 0.2307
#   Batch 48/49 - Loss: 0.2085
#   Batch 49/49 - Loss: 0.1954
# Epoch 16 Completed ✅ | Train Loss: 0.2051 | Val Loss: 0.4053
#
# Epoch 17/1000
#   Batch 1/49 - Loss: 0.2155
#   Batch 2/49 - Loss: 0.1880
#   Batch 3/49 - Loss: 0.1962
#   Batch 4/49 - Loss: 0.2324
#   Batch 5/49 - Loss: 0.1863
#   Batch 6/49 - Loss: 0.2072
#   Batch 7/49 - Loss: 0.2246
#   Batch 8/49 - Loss: 0.2357
#   Batch 9/49 - Loss: 0.2009
#   Batch 10/49 - Loss: 0.2180
#   Batch 11/49 - Loss: 0.2115
#   Batch 12/49 - Loss: 0.2074
#   Batch 13/49 - Loss: 0.2050
#   Batch 14/49 - Loss: 0.2313
#   Batch 15/49 - Loss: 0.2077
#   Batch 16/49 - Loss: 0.1922
#   Batch 17/49 - Loss: 0.1965
#   Batch 18/49 - Loss: 0.1924
#   Batch 19/49 - Loss: 0.1826
#   Batch 20/49 - Loss: 0.2196
#   Batch 21/49 - Loss: 0.2307
#   Batch 22/49 - Loss: 0.2015
#   Batch 23/49 - Loss: 0.1824
#   Batch 24/49 - Loss: 0.2104
#   Batch 25/49 - Loss: 0.2039
#   Batch 26/49 - Loss: 0.2288
#   Batch 27/49 - Loss: 0.2161
#   Batch 28/49 - Loss: 0.1954
#   Batch 29/49 - Loss: 0.2239
#   Batch 30/49 - Loss: 0.1844
#   Batch 31/49 - Loss: 0.1903
#   Batch 32/49 - Loss: 0.1766
#   Batch 33/49 - Loss: 0.2108
#   Batch 34/49 - Loss: 0.2055
#   Batch 35/49 - Loss: 0.1996
#   Batch 36/49 - Loss: 0.2062
#   Batch 37/49 - Loss: 0.1952
#   Batch 38/49 - Loss: 0.2021
#   Batch 39/49 - Loss: 0.2284
#   Batch 40/49 - Loss: 0.1965
#   Batch 41/49 - Loss: 0.1872
#   Batch 42/49 - Loss: 0.2055
#   Batch 43/49 - Loss: 0.2237
#   Batch 44/49 - Loss: 0.2007
#   Batch 45/49 - Loss: 0.2085
#   Batch 46/49 - Loss: 0.1986
#   Batch 47/49 - Loss: 0.1934
#   Batch 48/49 - Loss: 0.2039
#   Batch 49/49 - Loss: 0.1699
# Epoch 17 Completed ✅ | Train Loss: 0.2047 | Val Loss: 0.3645
# ✅ Saved best model at epoch 17 with val_loss 0.3645
#
# Epoch 18/1000
#   Batch 1/49 - Loss: 0.1952
#   Batch 2/49 - Loss: 0.1832
#   Batch 3/49 - Loss: 0.2183
#   Batch 4/49 - Loss: 0.2491
#   Batch 5/49 - Loss: 0.2113
#   Batch 6/49 - Loss: 0.1911
#   Batch 7/49 - Loss: 0.2039
#   Batch 8/49 - Loss: 0.2176
#   Batch 9/49 - Loss: 0.2122
#   Batch 10/49 - Loss: 0.2306
#   Batch 11/49 - Loss: 0.2111
#   Batch 12/49 - Loss: 0.1996
#   Batch 13/49 - Loss: 0.2007
#   Batch 14/49 - Loss: 0.2214
#   Batch 15/49 - Loss: 0.2211
#   Batch 16/49 - Loss: 0.1846
#   Batch 17/49 - Loss: 0.2044
#   Batch 18/49 - Loss: 0.2042
#   Batch 19/49 - Loss: 0.2101
#   Batch 20/49 - Loss: 0.1822
#   Batch 21/49 - Loss: 0.1919
#   Batch 22/49 - Loss: 0.1909
#   Batch 23/49 - Loss: 0.1900
#   Batch 24/49 - Loss: 0.1843
#   Batch 25/49 - Loss: 0.1818
#   Batch 26/49 - Loss: 0.2132
#   Batch 27/49 - Loss: 0.1902
#   Batch 28/49 - Loss: 0.2132
#   Batch 29/49 - Loss: 0.1994
#   Batch 30/49 - Loss: 0.2103
#   Batch 31/49 - Loss: 0.1828
#   Batch 32/49 - Loss: 0.1993
#   Batch 33/49 - Loss: 0.2133
#   Batch 34/49 - Loss: 0.2005
#   Batch 35/49 - Loss: 0.2004
#   Batch 36/49 - Loss: 0.1834
#   Batch 37/49 - Loss: 0.2245
#   Batch 38/49 - Loss: 0.1986
#   Batch 39/49 - Loss: 0.2206
#   Batch 40/49 - Loss: 0.2098
#   Batch 41/49 - Loss: 0.2169
#   Batch 42/49 - Loss: 0.1938
#   Batch 43/49 - Loss: 0.1917
#   Batch 44/49 - Loss: 0.2366
#   Batch 45/49 - Loss: 0.2136
#   Batch 46/49 - Loss: 0.2022
#   Batch 47/49 - Loss: 0.1882
#   Batch 48/49 - Loss: 0.2309
#   Batch 49/49 - Loss: 0.2044
# Epoch 18 Completed ✅ | Train Loss: 0.2047 | Val Loss: 0.3698
#
# Epoch 19/1000
#   Batch 1/49 - Loss: 0.1847
#   Batch 2/49 - Loss: 0.1837
#   Batch 3/49 - Loss: 0.2122
#   Batch 4/49 - Loss: 0.2101
#   Batch 5/49 - Loss: 0.1928
#   Batch 6/49 - Loss: 0.2071
#   Batch 7/49 - Loss: 0.1942
#   Batch 8/49 - Loss: 0.2134
#   Batch 9/49 - Loss: 0.2180
#   Batch 10/49 - Loss: 0.2029
#   Batch 11/49 - Loss: 0.1901
#   Batch 12/49 - Loss: 0.2116
#   Batch 13/49 - Loss: 0.1762
#   Batch 14/49 - Loss: 0.2209
#   Batch 15/49 - Loss: 0.2037
#   Batch 16/49 - Loss: 0.2209
#   Batch 17/49 - Loss: 0.1959
#   Batch 18/49 - Loss: 0.1509
#   Batch 19/49 - Loss: 0.1993
#   Batch 20/49 - Loss: 0.2241
#   Batch 21/49 - Loss: 0.2011
#   Batch 22/49 - Loss: 0.1969
#   Batch 23/49 - Loss: 0.1997
#   Batch 24/49 - Loss: 0.2015
#   Batch 25/49 - Loss: 0.1834
#   Batch 26/49 - Loss: 0.1952
#   Batch 27/49 - Loss: 0.2102
#   Batch 28/49 - Loss: 0.2022
#   Batch 29/49 - Loss: 0.2082
#   Batch 30/49 - Loss: 0.1990
#   Batch 31/49 - Loss: 0.2049
#   Batch 32/49 - Loss: 0.2021
#   Batch 33/49 - Loss: 0.1863
#   Batch 34/49 - Loss: 0.1912
#   Batch 35/49 - Loss: 0.1915
#   Batch 36/49 - Loss: 0.1997
#   Batch 37/49 - Loss: 0.2140
#   Batch 38/49 - Loss: 0.1914
#   Batch 39/49 - Loss: 0.2058
#   Batch 40/49 - Loss: 0.1886
#   Batch 41/49 - Loss: 0.2449
#   Batch 42/49 - Loss: 0.1799
#   Batch 43/49 - Loss: 0.2020
#   Batch 44/49 - Loss: 0.2012
#   Batch 45/49 - Loss: 0.2349
#   Batch 46/49 - Loss: 0.1978
#   Batch 47/49 - Loss: 0.1891
#   Batch 48/49 - Loss: 0.2100
#   Batch 49/49 - Loss: 0.2457
# Epoch 19 Completed ✅ | Train Loss: 0.2019 | Val Loss: 0.4017
#
# Epoch 20/1000
#   Batch 1/49 - Loss: 0.1821
#   Batch 2/49 - Loss: 0.2262
#   Batch 3/49 - Loss: 0.2346
#   Batch 4/49 - Loss: 0.1821
#   Batch 5/49 - Loss: 0.2144
#   Batch 6/49 - Loss: 0.1701
#   Batch 7/49 - Loss: 0.2228
#   Batch 8/49 - Loss: 0.2032
#   Batch 9/49 - Loss: 0.2103
#   Batch 10/49 - Loss: 0.1957
#   Batch 11/49 - Loss: 0.2235
#   Batch 12/49 - Loss: 0.1883
#   Batch 13/49 - Loss: 0.1781
#   Batch 14/49 - Loss: 0.2289
#   Batch 15/49 - Loss: 0.2090
#   Batch 16/49 - Loss: 0.2081
#   Batch 17/49 - Loss: 0.2259
#   Batch 18/49 - Loss: 0.1829
#   Batch 19/49 - Loss: 0.1898
#   Batch 20/49 - Loss: 0.2061
#   Batch 21/49 - Loss: 0.2040
#   Batch 22/49 - Loss: 0.2377
#   Batch 23/49 - Loss: 0.2027
#   Batch 24/49 - Loss: 0.1949
#   Batch 25/49 - Loss: 0.1915
#   Batch 26/49 - Loss: 0.1984
#   Batch 27/49 - Loss: 0.1970
#   Batch 28/49 - Loss: 0.2109
#   Batch 29/49 - Loss: 0.1935
#   Batch 30/49 - Loss: 0.2030
#   Batch 31/49 - Loss: 0.1735
#   Batch 32/49 - Loss: 0.1891
#   Batch 33/49 - Loss: 0.1785
#   Batch 34/49 - Loss: 0.1975
#   Batch 35/49 - Loss: 0.2015
#   Batch 36/49 - Loss: 0.2207
#   Batch 37/49 - Loss: 0.2372
#   Batch 38/49 - Loss: 0.2222
#   Batch 39/49 - Loss: 0.1900
#   Batch 40/49 - Loss: 0.2229
#   Batch 41/49 - Loss: 0.2096
#   Batch 42/49 - Loss: 0.1994
#   Batch 43/49 - Loss: 0.2079
#   Batch 44/49 - Loss: 0.1899
#   Batch 45/49 - Loss: 0.2096
#   Batch 46/49 - Loss: 0.2099
#   Batch 47/49 - Loss: 0.2142
#   Batch 48/49 - Loss: 0.2279
#   Batch 49/49 - Loss: 0.1935
# Epoch 20 Completed ✅ | Train Loss: 0.2043 | Val Loss: 0.3872
#
# Epoch 21/1000
#   Batch 1/49 - Loss: 0.2012
#   Batch 2/49 - Loss: 0.2091
#   Batch 3/49 - Loss: 0.2064
#   Batch 4/49 - Loss: 0.1967
#   Batch 5/49 - Loss: 0.2051
#   Batch 6/49 - Loss: 0.2143
#   Batch 7/49 - Loss: 0.1971
#   Batch 8/49 - Loss: 0.1896
#   Batch 9/49 - Loss: 0.1978
#   Batch 10/49 - Loss: 0.1972
#   Batch 11/49 - Loss: 0.2114
#   Batch 12/49 - Loss: 0.1932
#   Batch 13/49 - Loss: 0.2326
#   Batch 14/49 - Loss: 0.2072
#   Batch 15/49 - Loss: 0.2064
#   Batch 16/49 - Loss: 0.2006
#   Batch 17/49 - Loss: 0.2022
#   Batch 18/49 - Loss: 0.2216
#   Batch 19/49 - Loss: 0.1885
#   Batch 20/49 - Loss: 0.2187
#   Batch 21/49 - Loss: 0.1982
#   Batch 22/49 - Loss: 0.2210
#   Batch 23/49 - Loss: 0.1863
#   Batch 24/49 - Loss: 0.2263
#   Batch 25/49 - Loss: 0.2045
#   Batch 26/49 - Loss: 0.1707
#   Batch 27/49 - Loss: 0.2029
#   Batch 28/49 - Loss: 0.1874
#   Batch 29/49 - Loss: 0.1945
#   Batch 30/49 - Loss: 0.2179
#   Batch 31/49 - Loss: 0.2070
#   Batch 32/49 - Loss: 0.1984
#   Batch 33/49 - Loss: 0.2066
#   Batch 34/49 - Loss: 0.1951
#   Batch 35/49 - Loss: 0.1973
#   Batch 36/49 - Loss: 0.1925
#   Batch 37/49 - Loss: 0.1875
#   Batch 38/49 - Loss: 0.2152
#   Batch 39/49 - Loss: 0.1754
#   Batch 40/49 - Loss: 0.1833
#   Batch 41/49 - Loss: 0.2052
#   Batch 42/49 - Loss: 0.1811
#   Batch 43/49 - Loss: 0.1955
#   Batch 44/49 - Loss: 0.1844
#   Batch 45/49 - Loss: 0.2140
#   Batch 46/49 - Loss: 0.1952
#   Batch 47/49 - Loss: 0.1777
#   Batch 48/49 - Loss: 0.2112
#   Batch 49/49 - Loss: 0.2105
# Epoch 21 Completed ✅ | Train Loss: 0.2008 | Val Loss: 0.3594
# ✅ Saved best model at epoch 21 with val_loss 0.3594
#
# Epoch 22/1000
#   Batch 1/49 - Loss: 0.1964
#   Batch 2/49 - Loss: 0.1945
#   Batch 3/49 - Loss: 0.1992
#   Batch 4/49 - Loss: 0.1830
#   Batch 5/49 - Loss: 0.1997
#   Batch 6/49 - Loss: 0.2115
#   Batch 7/49 - Loss: 0.1996
#   Batch 8/49 - Loss: 0.2098
#   Batch 9/49 - Loss: 0.2082
#   Batch 10/49 - Loss: 0.1782
#   Batch 11/49 - Loss: 0.1652
#   Batch 12/49 - Loss: 0.2111
#   Batch 13/49 - Loss: 0.1983
#   Batch 14/49 - Loss: 0.1938
#   Batch 15/49 - Loss: 0.1907
#   Batch 16/49 - Loss: 0.1720
#   Batch 17/49 - Loss: 0.1913
#   Batch 18/49 - Loss: 0.1821
#   Batch 19/49 - Loss: 0.2347
#   Batch 20/49 - Loss: 0.2152
#   Batch 21/49 - Loss: 0.2037
#   Batch 22/49 - Loss: 0.2061
#   Batch 23/49 - Loss: 0.2152
#   Batch 24/49 - Loss: 0.2043
#   Batch 25/49 - Loss: 0.2046
#   Batch 26/49 - Loss: 0.1962
#   Batch 27/49 - Loss: 0.1716
#   Batch 28/49 - Loss: 0.2080
#   Batch 29/49 - Loss: 0.1819
#   Batch 30/49 - Loss: 0.1962
#   Batch 31/49 - Loss: 0.1898
#   Batch 32/49 - Loss: 0.1890
#   Batch 33/49 - Loss: 0.2068
#   Batch 34/49 - Loss: 0.2096
#   Batch 35/49 - Loss: 0.1829
#   Batch 36/49 - Loss: 0.2125
#   Batch 37/49 - Loss: 0.2002
#   Batch 38/49 - Loss: 0.1882
#   Batch 39/49 - Loss: 0.1973
#   Batch 40/49 - Loss: 0.2078
#   Batch 41/49 - Loss: 0.1941
#   Batch 42/49 - Loss: 0.2122
#   Batch 43/49 - Loss: 0.1942
#   Batch 44/49 - Loss: 0.1907
#   Batch 45/49 - Loss: 0.1915
#   Batch 46/49 - Loss: 0.1968
#   Batch 47/49 - Loss: 0.2035
#   Batch 48/49 - Loss: 0.1840
#   Batch 49/49 - Loss: 0.2566
# Epoch 22 Completed ✅ | Train Loss: 0.1986 | Val Loss: 0.3793
#
# Epoch 23/1000
#   Batch 1/49 - Loss: 0.2018
#   Batch 2/49 - Loss: 0.1988
#   Batch 3/49 - Loss: 0.2139
#   Batch 4/49 - Loss: 0.2176
#   Batch 5/49 - Loss: 0.1962
#   Batch 6/49 - Loss: 0.1889
#   Batch 7/49 - Loss: 0.2047
#   Batch 8/49 - Loss: 0.2268
#   Batch 9/49 - Loss: 0.2049
#   Batch 10/49 - Loss: 0.2339
#   Batch 11/49 - Loss: 0.1895
#   Batch 12/49 - Loss: 0.2147
#   Batch 13/49 - Loss: 0.1916
#   Batch 14/49 - Loss: 0.2020
#   Batch 15/49 - Loss: 0.1867
#   Batch 16/49 - Loss: 0.1872
#   Batch 17/49 - Loss: 0.1938
#   Batch 18/49 - Loss: 0.1835
#   Batch 19/49 - Loss: 0.1986
#   Batch 20/49 - Loss: 0.2002
#   Batch 21/49 - Loss: 0.1926
#   Batch 22/49 - Loss: 0.1849
#   Batch 23/49 - Loss: 0.1860
#   Batch 24/49 - Loss: 0.2036
#   Batch 25/49 - Loss: 0.1730
#   Batch 26/49 - Loss: 0.1840
#   Batch 27/49 - Loss: 0.2164
#   Batch 28/49 - Loss: 0.1821
#   Batch 29/49 - Loss: 0.1894
#   Batch 30/49 - Loss: 0.2263
#   Batch 31/49 - Loss: 0.1989
#   Batch 32/49 - Loss: 0.2211
#   Batch 33/49 - Loss: 0.1744
#   Batch 34/49 - Loss: 0.1864
#   Batch 35/49 - Loss: 0.1993
#   Batch 36/49 - Loss: 0.2029
#   Batch 37/49 - Loss: 0.1887
#   Batch 38/49 - Loss: 0.1985
#   Batch 39/49 - Loss: 0.2077
#   Batch 40/49 - Loss: 0.1904
#   Batch 41/49 - Loss: 0.1942
#   Batch 42/49 - Loss: 0.1872
#   Batch 43/49 - Loss: 0.2021
#   Batch 44/49 - Loss: 0.1795
#   Batch 45/49 - Loss: 0.1967
#   Batch 46/49 - Loss: 0.1984
#   Batch 47/49 - Loss: 0.2093
#   Batch 48/49 - Loss: 0.1852
#   Batch 49/49 - Loss: 0.2236
# Epoch 23 Completed ✅ | Train Loss: 0.1983 | Val Loss: 0.4030
#
# Epoch 24/1000
#   Batch 1/49 - Loss: 0.1884
#   Batch 2/49 - Loss: 0.1841
#   Batch 3/49 - Loss: 0.2188
#   Batch 4/49 - Loss: 0.1854
#   Batch 5/49 - Loss: 0.2039
#   Batch 6/49 - Loss: 0.1878
#   Batch 7/49 - Loss: 0.1941
#   Batch 8/49 - Loss: 0.1881
#   Batch 9/49 - Loss: 0.1690
#   Batch 10/49 - Loss: 0.1818
#   Batch 11/49 - Loss: 0.2015
#   Batch 12/49 - Loss: 0.1801
#   Batch 13/49 - Loss: 0.1749
#   Batch 14/49 - Loss: 0.2022
#   Batch 15/49 - Loss: 0.1959
#   Batch 16/49 - Loss: 0.1668
#   Batch 17/49 - Loss: 0.1884
#   Batch 18/49 - Loss: 0.2119
#   Batch 19/49 - Loss: 0.2163
#   Batch 20/49 - Loss: 0.1925
#   Batch 21/49 - Loss: 0.1885
#   Batch 22/49 - Loss: 0.1986
#   Batch 23/49 - Loss: 0.2018
#   Batch 24/49 - Loss: 0.2050
#   Batch 25/49 - Loss: 0.1935
#   Batch 26/49 - Loss: 0.1762
#   Batch 27/49 - Loss: 0.1943
#   Batch 28/49 - Loss: 0.2128
#   Batch 29/49 - Loss: 0.2068
#   Batch 30/49 - Loss: 0.2096
#   Batch 31/49 - Loss: 0.1870
#   Batch 32/49 - Loss: 0.2099
#   Batch 33/49 - Loss: 0.2142
#   Batch 34/49 - Loss: 0.1955
#   Batch 35/49 - Loss: 0.1989
#   Batch 36/49 - Loss: 0.2102
#   Batch 37/49 - Loss: 0.1872
#   Batch 38/49 - Loss: 0.1860
#   Batch 39/49 - Loss: 0.2289
#   Batch 40/49 - Loss: 0.1786
#   Batch 41/49 - Loss: 0.1939
#   Batch 42/49 - Loss: 0.2223
#   Batch 43/49 - Loss: 0.2052
#   Batch 44/49 - Loss: 0.1896
#   Batch 45/49 - Loss: 0.1792
#   Batch 46/49 - Loss: 0.2088
#   Batch 47/49 - Loss: 0.1803
#   Batch 48/49 - Loss: 0.2110
#   Batch 49/49 - Loss: 0.2409
# Epoch 24 Completed ✅ | Train Loss: 0.1969 | Val Loss: 0.3481
# ✅ Saved best model at epoch 24 with val_loss 0.3481
#
# Epoch 25/1000
#   Batch 1/49 - Loss: 0.2150
#   Batch 2/49 - Loss: 0.1776
#   Batch 3/49 - Loss: 0.2242
#   Batch 4/49 - Loss: 0.1792
#   Batch 5/49 - Loss: 0.1850
#   Batch 6/49 - Loss: 0.1932
#   Batch 7/49 - Loss: 0.1775
#   Batch 8/49 - Loss: 0.1979
#   Batch 9/49 - Loss: 0.1922
#   Batch 10/49 - Loss: 0.2021
#   Batch 11/49 - Loss: 0.1715
#   Batch 12/49 - Loss: 0.2044
#   Batch 13/49 - Loss: 0.1754
#   Batch 14/49 - Loss: 0.1980
#   Batch 15/49 - Loss: 0.1955
#   Batch 16/49 - Loss: 0.1847
#   Batch 17/49 - Loss: 0.2030
#   Batch 18/49 - Loss: 0.1844
#   Batch 19/49 - Loss: 0.1693
#   Batch 20/49 - Loss: 0.1897
#   Batch 21/49 - Loss: 0.1720
#   Batch 22/49 - Loss: 0.2120
#   Batch 23/49 - Loss: 0.1997
#   Batch 24/49 - Loss: 0.2067
#   Batch 25/49 - Loss: 0.1947
#   Batch 26/49 - Loss: 0.2149
#   Batch 27/49 - Loss: 0.1945
#   Batch 28/49 - Loss: 0.1788
#   Batch 29/49 - Loss: 0.1802
#   Batch 30/49 - Loss: 0.1772
#   Batch 31/49 - Loss: 0.2132
#   Batch 32/49 - Loss: 0.2091
#   Batch 33/49 - Loss: 0.1915
#   Batch 34/49 - Loss: 0.1872
#   Batch 35/49 - Loss: 0.2105
#   Batch 36/49 - Loss: 0.1984
#   Batch 37/49 - Loss: 0.2073
#   Batch 38/49 - Loss: 0.2152
#   Batch 39/49 - Loss: 0.2060
#   Batch 40/49 - Loss: 0.1707
#   Batch 41/49 - Loss: 0.1929
#   Batch 42/49 - Loss: 0.1976
#   Batch 43/49 - Loss: 0.1863
#   Batch 44/49 - Loss: 0.1925
#   Batch 45/49 - Loss: 0.2149
#   Batch 46/49 - Loss: 0.1488
#   Batch 47/49 - Loss: 0.1868
#   Batch 48/49 - Loss: 0.2133
#   Batch 49/49 - Loss: 0.1995
# Epoch 25 Completed ✅ | Train Loss: 0.1937 | Val Loss: 0.3680
#
# Epoch 26/1000
#   Batch 1/49 - Loss: 0.2028
#   Batch 2/49 - Loss: 0.1891
#   Batch 3/49 - Loss: 0.1876
#   Batch 4/49 - Loss: 0.1811
#   Batch 5/49 - Loss: 0.1962
#   Batch 6/49 - Loss: 0.2086
#   Batch 7/49 - Loss: 0.1945
#   Batch 8/49 - Loss: 0.2056
#   Batch 9/49 - Loss: 0.1844
#   Batch 10/49 - Loss: 0.1868
#   Batch 11/49 - Loss: 0.2261
#   Batch 12/49 - Loss: 0.1751
#   Batch 13/49 - Loss: 0.1817
#   Batch 14/49 - Loss: 0.1919
#   Batch 15/49 - Loss: 0.2158
#   Batch 16/49 - Loss: 0.1747
#   Batch 17/49 - Loss: 0.2139
#   Batch 18/49 - Loss: 0.1956
#   Batch 19/49 - Loss: 0.1969
#   Batch 20/49 - Loss: 0.1981
#   Batch 21/49 - Loss: 0.2108
#   Batch 22/49 - Loss: 0.2130
#   Batch 23/49 - Loss: 0.1833
#   Batch 24/49 - Loss: 0.2265
#   Batch 25/49 - Loss: 0.2106
#   Batch 26/49 - Loss: 0.1923
#   Batch 27/49 - Loss: 0.1971
#   Batch 28/49 - Loss: 0.2211
#   Batch 29/49 - Loss: 0.1903
#   Batch 30/49 - Loss: 0.2015
#   Batch 31/49 - Loss: 0.1875
#   Batch 32/49 - Loss: 0.2039
#   Batch 33/49 - Loss: 0.1852
#   Batch 34/49 - Loss: 0.2027
#   Batch 35/49 - Loss: 0.1731
#   Batch 36/49 - Loss: 0.1912
#   Batch 37/49 - Loss: 0.1775
#   Batch 38/49 - Loss: 0.1888
#   Batch 39/49 - Loss: 0.2016
#   Batch 40/49 - Loss: 0.2167
#   Batch 41/49 - Loss: 0.1624
#   Batch 42/49 - Loss: 0.2064
#   Batch 43/49 - Loss: 0.1963
#   Batch 44/49 - Loss: 0.1988
#   Batch 45/49 - Loss: 0.1731
#   Batch 46/49 - Loss: 0.1947
#   Batch 47/49 - Loss: 0.1774
#   Batch 48/49 - Loss: 0.1860
#   Batch 49/49 - Loss: 0.2544
# Epoch 26 Completed ✅ | Train Loss: 0.1965 | Val Loss: 0.3594
#
# Epoch 27/1000
#   Batch 1/49 - Loss: 0.1831
#   Batch 2/49 - Loss: 0.1835
#   Batch 3/49 - Loss: 0.1834
#   Batch 4/49 - Loss: 0.1603
#   Batch 5/49 - Loss: 0.1994
#   Batch 6/49 - Loss: 0.1999
#   Batch 7/49 - Loss: 0.1979
#   Batch 8/49 - Loss: 0.1883
#   Batch 9/49 - Loss: 0.1717
#   Batch 10/49 - Loss: 0.2435
#   Batch 11/49 - Loss: 0.2086
#   Batch 12/49 - Loss: 0.1924
#   Batch 13/49 - Loss: 0.1966
#   Batch 14/49 - Loss: 0.1919
#   Batch 15/49 - Loss: 0.1962
#   Batch 16/49 - Loss: 0.1805
#   Batch 17/49 - Loss: 0.1774
#   Batch 18/49 - Loss: 0.2009
#   Batch 19/49 - Loss: 0.1783
#   Batch 20/49 - Loss: 0.1863
#   Batch 21/49 - Loss: 0.1805
#   Batch 22/49 - Loss: 0.1857
#   Batch 23/49 - Loss: 0.1951
#   Batch 24/49 - Loss: 0.2027
#   Batch 25/49 - Loss: 0.2122
#   Batch 26/49 - Loss: 0.2043
#   Batch 27/49 - Loss: 0.2017
#   Batch 28/49 - Loss: 0.1960
#   Batch 29/49 - Loss: 0.1762
#   Batch 30/49 - Loss: 0.2222
#   Batch 31/49 - Loss: 0.2020
#   Batch 32/49 - Loss: 0.1822
#   Batch 33/49 - Loss: 0.2007
#   Batch 34/49 - Loss: 0.1985
#   Batch 35/49 - Loss: 0.2015
#   Batch 36/49 - Loss: 0.1897
#   Batch 37/49 - Loss: 0.1872
#   Batch 38/49 - Loss: 0.1961
#   Batch 39/49 - Loss: 0.1969
#   Batch 40/49 - Loss: 0.2091
#   Batch 41/49 - Loss: 0.1951
#   Batch 42/49 - Loss: 0.2071
#   Batch 43/49 - Loss: 0.1998
#   Batch 44/49 - Loss: 0.2170
#   Batch 45/49 - Loss: 0.2043
#   Batch 46/49 - Loss: 0.1816
#   Batch 47/49 - Loss: 0.1842
#   Batch 48/49 - Loss: 0.1982
#   Batch 49/49 - Loss: 0.2089
# Epoch 27 Completed ✅ | Train Loss: 0.1950 | Val Loss: 0.3584
#
# Epoch 28/1000
#   Batch 1/49 - Loss: 0.1780
#   Batch 2/49 - Loss: 0.2061
#   Batch 3/49 - Loss: 0.2072
#   Batch 4/49 - Loss: 0.2026
#   Batch 5/49 - Loss: 0.2056
#   Batch 6/49 - Loss: 0.2230
#   Batch 7/49 - Loss: 0.2135
#   Batch 8/49 - Loss: 0.1804
#   Batch 9/49 - Loss: 0.1892
#   Batch 10/49 - Loss: 0.1904
#   Batch 11/49 - Loss: 0.2141
#   Batch 12/49 - Loss: 0.1662
#   Batch 13/49 - Loss: 0.1932
#   Batch 14/49 - Loss: 0.1716
#   Batch 15/49 - Loss: 0.1953
#   Batch 16/49 - Loss: 0.2020
#   Batch 17/49 - Loss: 0.1817
#   Batch 18/49 - Loss: 0.1838
#   Batch 19/49 - Loss: 0.2070
#   Batch 20/49 - Loss: 0.1868
#   Batch 21/49 - Loss: 0.2234
#   Batch 22/49 - Loss: 0.1863
#   Batch 23/49 - Loss: 0.2234
#   Batch 24/49 - Loss: 0.1930
#   Batch 25/49 - Loss: 0.1818
#   Batch 26/49 - Loss: 0.1851
#   Batch 27/49 - Loss: 0.1898
#   Batch 28/49 - Loss: 0.1830
#   Batch 29/49 - Loss: 0.1697
#   Batch 30/49 - Loss: 0.1874
#   Batch 31/49 - Loss: 0.1818
#   Batch 32/49 - Loss: 0.1811
#   Batch 33/49 - Loss: 0.1873
#   Batch 34/49 - Loss: 0.2042
#   Batch 35/49 - Loss: 0.1964
#   Batch 36/49 - Loss: 0.1821
#   Batch 37/49 - Loss: 0.2084
#   Batch 38/49 - Loss: 0.1921
#   Batch 39/49 - Loss: 0.2001
#   Batch 40/49 - Loss: 0.1944
#   Batch 41/49 - Loss: 0.2042
#   Batch 42/49 - Loss: 0.1978
#   Batch 43/49 - Loss: 0.1948
#   Batch 44/49 - Loss: 0.2139
#   Batch 45/49 - Loss: 0.1797
#   Batch 46/49 - Loss: 0.1720
#   Batch 47/49 - Loss: 0.1990
#   Batch 48/49 - Loss: 0.1984
#   Batch 49/49 - Loss: 0.1993
# Epoch 28 Completed ✅ | Train Loss: 0.1940 | Val Loss: 0.3480
# ✅ Saved best model at epoch 28 with val_loss 0.3480
#
# Epoch 29/1000
#   Batch 1/49 - Loss: 0.2004
#   Batch 2/49 - Loss: 0.1911
#   Batch 3/49 - Loss: 0.1768
#   Batch 4/49 - Loss: 0.2078
#   Batch 5/49 - Loss: 0.1943
#   Batch 6/49 - Loss: 0.1868
#   Batch 7/49 - Loss: 0.2014
#   Batch 8/49 - Loss: 0.1988
#   Batch 9/49 - Loss: 0.1896
#   Batch 10/49 - Loss: 0.1823
#   Batch 11/49 - Loss: 0.1999
#   Batch 12/49 - Loss: 0.2211
#   Batch 13/49 - Loss: 0.1597
#   Batch 14/49 - Loss: 0.1880
#   Batch 15/49 - Loss: 0.1903
#   Batch 16/49 - Loss: 0.1918
#   Batch 17/49 - Loss: 0.1753
#   Batch 18/49 - Loss: 0.1730
#   Batch 19/49 - Loss: 0.2000
#   Batch 20/49 - Loss: 0.1958
#   Batch 21/49 - Loss: 0.1754
#   Batch 22/49 - Loss: 0.1830
#   Batch 23/49 - Loss: 0.1898
#   Batch 24/49 - Loss: 0.1858
#   Batch 25/49 - Loss: 0.2072
#   Batch 26/49 - Loss: 0.1752
#   Batch 27/49 - Loss: 0.2095
#   Batch 28/49 - Loss: 0.2167
#   Batch 29/49 - Loss: 0.1968
#   Batch 30/49 - Loss: 0.1756
#   Batch 31/49 - Loss: 0.1745
#   Batch 32/49 - Loss: 0.2006
#   Batch 33/49 - Loss: 0.1959
#   Batch 34/49 - Loss: 0.2047
#   Batch 35/49 - Loss: 0.1870
#   Batch 36/49 - Loss: 0.1613
#   Batch 37/49 - Loss: 0.2035
#   Batch 38/49 - Loss: 0.1900
#   Batch 39/49 - Loss: 0.1968
#   Batch 40/49 - Loss: 0.1954
#   Batch 41/49 - Loss: 0.1499
#   Batch 42/49 - Loss: 0.1892
#   Batch 43/49 - Loss: 0.2050
#   Batch 44/49 - Loss: 0.1999
#   Batch 45/49 - Loss: 0.1943
#   Batch 46/49 - Loss: 0.1851
#   Batch 47/49 - Loss: 0.1842
#   Batch 48/49 - Loss: 0.1855
#   Batch 49/49 - Loss: 0.1788
# Epoch 29 Completed ✅ | Train Loss: 0.1902 | Val Loss: 0.3506
#
# Epoch 30/1000
#   Batch 1/49 - Loss: 0.1766
#   Batch 2/49 - Loss: 0.2324
#   Batch 3/49 - Loss: 0.1935
#   Batch 4/49 - Loss: 0.2192
#   Batch 5/49 - Loss: 0.2007
#   Batch 6/49 - Loss: 0.1866
#   Batch 7/49 - Loss: 0.2164
#   Batch 8/49 - Loss: 0.1590
#   Batch 9/49 - Loss: 0.1635
#   Batch 10/49 - Loss: 0.1969
#   Batch 11/49 - Loss: 0.1818
#   Batch 12/49 - Loss: 0.1996
#   Batch 13/49 - Loss: 0.1874
#   Batch 14/49 - Loss: 0.1840
#   Batch 15/49 - Loss: 0.2234
#   Batch 16/49 - Loss: 0.1995
#   Batch 17/49 - Loss: 0.2194
#   Batch 18/49 - Loss: 0.1800
#   Batch 19/49 - Loss: 0.1730
#   Batch 20/49 - Loss: 0.1973
#   Batch 21/49 - Loss: 0.2067
#   Batch 22/49 - Loss: 0.2036
#   Batch 23/49 - Loss: 0.1703
#   Batch 24/49 - Loss: 0.1901
#   Batch 25/49 - Loss: 0.1736
#   Batch 26/49 - Loss: 0.1958
#   Batch 27/49 - Loss: 0.1908
#   Batch 28/49 - Loss: 0.1885
#   Batch 29/49 - Loss: 0.1696
#   Batch 30/49 - Loss: 0.1997
#   Batch 31/49 - Loss: 0.2056
#   Batch 32/49 - Loss: 0.2064
#   Batch 33/49 - Loss: 0.2051
#   Batch 34/49 - Loss: 0.1828
#   Batch 35/49 - Loss: 0.2141
#   Batch 36/49 - Loss: 0.1932
#   Batch 37/49 - Loss: 0.2219
#   Batch 38/49 - Loss: 0.1820
#   Batch 39/49 - Loss: 0.1894
#   Batch 40/49 - Loss: 0.1892
#   Batch 41/49 - Loss: 0.1781
#   Batch 42/49 - Loss: 0.2116
#   Batch 43/49 - Loss: 0.1774
#   Batch 44/49 - Loss: 0.2062
#   Batch 45/49 - Loss: 0.1863
#   Batch 46/49 - Loss: 0.1894
#   Batch 47/49 - Loss: 0.2214
#   Batch 48/49 - Loss: 0.2078
#   Batch 49/49 - Loss: 0.2147
# Epoch 30 Completed ✅ | Train Loss: 0.1951 | Val Loss: 0.3435
# ✅ Saved best model at epoch 30 with val_loss 0.3435
#
# Epoch 31/1000
#   Batch 1/49 - Loss: 0.1779
#   Batch 2/49 - Loss: 0.1998
#   Batch 3/49 - Loss: 0.1711
#   Batch 4/49 - Loss: 0.1907
#   Batch 5/49 - Loss: 0.1739
#   Batch 6/49 - Loss: 0.2009
#   Batch 7/49 - Loss: 0.2094
#   Batch 8/49 - Loss: 0.2174
#   Batch 9/49 - Loss: 0.1837
#   Batch 10/49 - Loss: 0.1737
#   Batch 11/49 - Loss: 0.1646
#   Batch 12/49 - Loss: 0.1906
#   Batch 13/49 - Loss: 0.1801
#   Batch 14/49 - Loss: 0.1880
#   Batch 15/49 - Loss: 0.1873
#   Batch 16/49 - Loss: 0.2119
#   Batch 17/49 - Loss: 0.2044
#   Batch 18/49 - Loss: 0.1821
#   Batch 19/49 - Loss: 0.1925
#   Batch 20/49 - Loss: 0.1908
#   Batch 21/49 - Loss: 0.1877
#   Batch 22/49 - Loss: 0.1914
#   Batch 23/49 - Loss: 0.1978
#   Batch 24/49 - Loss: 0.1895
#   Batch 25/49 - Loss: 0.1800
#   Batch 26/49 - Loss: 0.1941
#   Batch 27/49 - Loss: 0.2074
#   Batch 28/49 - Loss: 0.1815
#   Batch 29/49 - Loss: 0.1901
#   Batch 30/49 - Loss: 0.1941
#   Batch 31/49 - Loss: 0.1752
#   Batch 32/49 - Loss: 0.1920
#   Batch 33/49 - Loss: 0.1755
#   Batch 34/49 - Loss: 0.1879
#   Batch 35/49 - Loss: 0.1809
#   Batch 36/49 - Loss: 0.1885
#   Batch 37/49 - Loss: 0.1843
#   Batch 38/49 - Loss: 0.1955
#   Batch 39/49 - Loss: 0.1865
#   Batch 40/49 - Loss: 0.1909
#   Batch 41/49 - Loss: 0.1951
#   Batch 42/49 - Loss: 0.1681
#   Batch 43/49 - Loss: 0.1747
#   Batch 44/49 - Loss: 0.1964
#   Batch 45/49 - Loss: 0.1994
#   Batch 46/49 - Loss: 0.1951
#   Batch 47/49 - Loss: 0.2115
#   Batch 48/49 - Loss: 0.1922
#   Batch 49/49 - Loss: 0.1739
# Epoch 31 Completed ✅ | Train Loss: 0.1891 | Val Loss: 0.4258
#
# Epoch 32/1000
#   Batch 1/49 - Loss: 0.1730
#   Batch 2/49 - Loss: 0.1848
#   Batch 3/49 - Loss: 0.1924
#   Batch 4/49 - Loss: 0.1898
#   Batch 5/49 - Loss: 0.1955
#   Batch 6/49 - Loss: 0.1876
#   Batch 7/49 - Loss: 0.1724
#   Batch 8/49 - Loss: 0.1917
#   Batch 9/49 - Loss: 0.1896
#   Batch 10/49 - Loss: 0.1766
#   Batch 11/49 - Loss: 0.1852
#   Batch 12/49 - Loss: 0.1783
#   Batch 13/49 - Loss: 0.1780
#   Batch 14/49 - Loss: 0.1849
#   Batch 15/49 - Loss: 0.2109
#   Batch 16/49 - Loss: 0.2195
#   Batch 17/49 - Loss: 0.2056
#   Batch 18/49 - Loss: 0.1765
#   Batch 19/49 - Loss: 0.1709
#   Batch 20/49 - Loss: 0.1957
#   Batch 21/49 - Loss: 0.1846
#   Batch 22/49 - Loss: 0.2074
#   Batch 23/49 - Loss: 0.2218
#   Batch 24/49 - Loss: 0.2054
#   Batch 25/49 - Loss: 0.2090
#   Batch 26/49 - Loss: 0.1876
#   Batch 27/49 - Loss: 0.1934
#   Batch 28/49 - Loss: 0.1981
#   Batch 29/49 - Loss: 0.1612
#   Batch 30/49 - Loss: 0.1844
#   Batch 31/49 - Loss: 0.1801
#   Batch 32/49 - Loss: 0.2148
#   Batch 33/49 - Loss: 0.1871
#   Batch 34/49 - Loss: 0.1677
#   Batch 35/49 - Loss: 0.1876
#   Batch 36/49 - Loss: 0.1689
# ...
#   Batch 16/49 - Loss: 0.1246
#   Batch 17/49 - Loss: 0.1303
#   Batch 18/49 - Loss: 0.1568
#   Batch 19/49 - Loss: 0.1045
#   Batch 20/49 - Loss: 0.1165
#   Batch 21/49 - Loss: 0.1223
#   Batch 22/49 - Loss: 0.1611
#   Batch 23/49 - Loss: 0.1296
#   Batch 24/49 - Loss: 0.1224
#   Batch 25/49 - Loss: 0.1350
#   Batch 26/49 - Loss: 0.1304
#   Batch 27/49 - Loss: 0.1367
#   Batch 28/49 - Loss: 0.1390
#   Batch 29/49 - Loss: 0.1322
#   Batch 30/49 - Loss: 0.1352
#   Batch 31/49 - Loss: 0.1224
#   Batch 32/49 - Loss: 0.1481
#   Batch 33/49 - Loss: 0.1302
#   Batch 34/49 - Loss: 0.1389
#   Batch 35/49 - Loss: 0.1339
#   Batch 36/49 - Loss: 0.1253
#   Batch 37/49 - Loss: 0.1371
#   Batch 38/49 - Loss: 0.1525
#   Batch 39/49 - Loss: 0.1442
#   Batch 40/49 - Loss: 0.1368
#   Batch 41/49 - Loss: 0.1490
#   Batch 42/49 - Loss: 0.1060
#   Batch 43/49 - Loss: 0.1163
#   Batch 44/49 - Loss: 0.1335
#   Batch 45/49 - Loss: 0.1340
#   Batch 46/49 - Loss: 0.1274
#   Batch 47/49 - Loss: 0.1213
#   Batch 48/49 - Loss: 0.1073
#   Batch 49/49 - Loss: 0.1091
# Epoch 213 Completed ✅ | Train Loss: 0.1319 | Val Loss: 0.3057
#
# Epoch 214/1000
#   Batch 1/49 - Loss: 0.1357
#   Batch 2/49 - Loss: 0.1382
#   Batch 3/49 - Loss: 0.1125
#   Batch 4/49 - Loss: 0.1166
#   Batch 5/49 - Loss: 0.1375
#   Batch 6/49 - Loss: 0.1236
#   Batch 7/49 - Loss: 0.1370
#   Batch 8/49 - Loss: 0.1374
#   Batch 9/49 - Loss: 0.1565
#   Batch 10/49 - Loss: 0.1262
#   Batch 11/49 - Loss: 0.1393
#   Batch 12/49 - Loss: 0.1082
#   Batch 13/49 - Loss: 0.1304
#   Batch 14/49 - Loss: 0.1406
#   Batch 15/49 - Loss: 0.1486
#   Batch 16/49 - Loss: 0.1245
#   Batch 17/49 - Loss: 0.1332
#   Batch 18/49 - Loss: 0.1354
#   Batch 19/49 - Loss: 0.1201
#   Batch 20/49 - Loss: 0.1212
#   Batch 21/49 - Loss: 0.1557
#   Batch 22/49 - Loss: 0.1338
#   Batch 23/49 - Loss: 0.1090
#   Batch 24/49 - Loss: 0.1352
#   Batch 25/49 - Loss: 0.1294
#   Batch 26/49 - Loss: 0.1387
#   Batch 27/49 - Loss: 0.1538
#   Batch 28/49 - Loss: 0.1102
#   Batch 29/49 - Loss: 0.1168
#   Batch 30/49 - Loss: 0.1181
#   Batch 31/49 - Loss: 0.1465
#   Batch 32/49 - Loss: 0.1238
#   Batch 33/49 - Loss: 0.1392
#   Batch 34/49 - Loss: 0.1212
#   Batch 35/49 - Loss: 0.1318
#   Batch 36/49 - Loss: 0.1425
#   Batch 37/49 - Loss: 0.1097
#   Batch 38/49 - Loss: 0.1596
#   Batch 39/49 - Loss: 0.1332
#   Batch 40/49 - Loss: 0.1539
#   Batch 41/49 - Loss: 0.1423
#   Batch 42/49 - Loss: 0.1407
#   Batch 43/49 - Loss: 0.1481
#   Batch 44/49 - Loss: 0.1346
#   Batch 45/49 - Loss: 0.1403
#   Batch 46/49 - Loss: 0.1290
#   Batch 47/49 - Loss: 0.1141
#   Batch 48/49 - Loss: 0.1495
#   Batch 49/49 - Loss: 0.1227
# Epoch 214 Completed ✅ | Train Loss: 0.1328 | Val Loss: 0.2993
#
# Epoch 215/1000
#   Batch 1/49 - Loss: 0.1337
#   Batch 2/49 - Loss: 0.1396
#   Batch 3/49 - Loss: 0.1366
#   Batch 4/49 - Loss: 0.1480
#   Batch 5/49 - Loss: 0.1151
#   Batch 6/49 - Loss: 0.1094
#   Batch 7/49 - Loss: 0.1216
#   Batch 8/49 - Loss: 0.1428
#   Batch 9/49 - Loss: 0.1287
#   Batch 10/49 - Loss: 0.1504
#   Batch 11/49 - Loss: 0.1239
#   Batch 12/49 - Loss: 0.1354
#   Batch 13/49 - Loss: 0.1271
#   Batch 14/49 - Loss: 0.1442
#   Batch 15/49 - Loss: 0.1223
#   Batch 16/49 - Loss: 0.1340
#   Batch 17/49 - Loss: 0.1475
#   Batch 18/49 - Loss: 0.1514
#   Batch 19/49 - Loss: 0.1536
#   Batch 20/49 - Loss: 0.1356
#   Batch 21/49 - Loss: 0.1442
#   Batch 22/49 - Loss: 0.1157
#   Batch 23/49 - Loss: 0.1519
#   Batch 24/49 - Loss: 0.1161
#   Batch 25/49 - Loss: 0.1272
#   Batch 26/49 - Loss: 0.1394
#   Batch 27/49 - Loss: 0.1563
#   Batch 28/49 - Loss: 0.1385
#   Batch 29/49 - Loss: 0.1364
#   Batch 30/49 - Loss: 0.1273
#   Batch 31/49 - Loss: 0.1287
#   Batch 32/49 - Loss: 0.1494
#   Batch 33/49 - Loss: 0.1204
#   Batch 34/49 - Loss: 0.1499
#   Batch 35/49 - Loss: 0.0990
#   Batch 36/49 - Loss: 0.1348
#   Batch 37/49 - Loss: 0.1365
#   Batch 38/49 - Loss: 0.1382
#   Batch 39/49 - Loss: 0.1442
#   Batch 40/49 - Loss: 0.1400
#   Batch 41/49 - Loss: 0.1285
#   Batch 42/49 - Loss: 0.1127
#   Batch 43/49 - Loss: 0.1651
#   Batch 44/49 - Loss: 0.1138
#   Batch 45/49 - Loss: 0.1195
#   Batch 46/49 - Loss: 0.1309
#   Batch 47/49 - Loss: 0.1449
#   Batch 48/49 - Loss: 0.1326
#   Batch 49/49 - Loss: 0.1104
# Epoch 215 Completed ✅ | Train Loss: 0.1337 | Val Loss: 0.2929
#
# Epoch 216/1000
#   Batch 1/49 - Loss: 0.1499
#   Batch 2/49 - Loss: 0.1347
#   Batch 3/49 - Loss: 0.1230
#   Batch 4/49 - Loss: 0.1232
#   Batch 5/49 - Loss: 0.1231
#   Batch 6/49 - Loss: 0.1430
#   Batch 7/49 - Loss: 0.1158
#   Batch 8/49 - Loss: 0.1350
#   Batch 9/49 - Loss: 0.1464
#   Batch 10/49 - Loss: 0.1298
#   Batch 11/49 - Loss: 0.1277
#   Batch 12/49 - Loss: 0.1180
#   Batch 13/49 - Loss: 0.1763
#   Batch 14/49 - Loss: 0.1195
#   Batch 15/49 - Loss: 0.1175
#   Batch 16/49 - Loss: 0.1532
#   Batch 17/49 - Loss: 0.1269
#   Batch 18/49 - Loss: 0.0979
#   Batch 19/49 - Loss: 0.1343
#   Batch 20/49 - Loss: 0.1242
#   Batch 21/49 - Loss: 0.1060
#   Batch 22/49 - Loss: 0.1475
#   Batch 23/49 - Loss: 0.1418
#   Batch 24/49 - Loss: 0.1395
#   Batch 25/49 - Loss: 0.1499
#   Batch 26/49 - Loss: 0.1383
#   Batch 27/49 - Loss: 0.1127
#   Batch 28/49 - Loss: 0.1354
#   Batch 29/49 - Loss: 0.1461
#   Batch 30/49 - Loss: 0.1593
#   Batch 31/49 - Loss: 0.1253
#   Batch 32/49 - Loss: 0.1353
#   Batch 33/49 - Loss: 0.1403
#   Batch 34/49 - Loss: 0.1411
#   Batch 35/49 - Loss: 0.1435
#   Batch 36/49 - Loss: 0.1380
#   Batch 37/49 - Loss: 0.1426
#   Batch 38/49 - Loss: 0.1422
#   Batch 39/49 - Loss: 0.1151
#   Batch 40/49 - Loss: 0.1317
#   Batch 41/49 - Loss: 0.1025
#   Batch 42/49 - Loss: 0.1446
#   Batch 43/49 - Loss: 0.1515
#   Batch 44/49 - Loss: 0.0961
#   Batch 45/49 - Loss: 0.1206
#   Batch 46/49 - Loss: 0.1195
#   Batch 47/49 - Loss: 0.1201
#   Batch 48/49 - Loss: 0.1166
#   Batch 49/49 - Loss: 0.1183
# Epoch 216 Completed ✅ | Train Loss: 0.1314 | Val Loss: 0.2928
#
# Epoch 217/1000
#   Batch 1/49 - Loss: 0.1262
#   Batch 2/49 - Loss: 0.1402
#   Batch 3/49 - Loss: 0.1478
#   Batch 4/49 - Loss: 0.1370
#   Batch 5/49 - Loss: 0.1115
#   Batch 6/49 - Loss: 0.1161
#   Batch 7/49 - Loss: 0.1119
#   Batch 8/49 - Loss: 0.1202
#   Batch 9/49 - Loss: 0.0963
#   Batch 10/49 - Loss: 0.1200
#   Batch 11/49 - Loss: 0.1319
#   Batch 12/49 - Loss: 0.1418
#   Batch 13/49 - Loss: 0.1175
#   Batch 14/49 - Loss: 0.1280
#   Batch 15/49 - Loss: 0.1455
#   Batch 16/49 - Loss: 0.1235
#   Batch 17/49 - Loss: 0.1173
#   Batch 18/49 - Loss: 0.1397
#   Batch 19/49 - Loss: 0.1182
#   Batch 20/49 - Loss: 0.1406
#   Batch 21/49 - Loss: 0.1244
#   Batch 22/49 - Loss: 0.1528
#   Batch 23/49 - Loss: 0.1438
#   Batch 24/49 - Loss: 0.1526
#   Batch 25/49 - Loss: 0.1437
#   Batch 26/49 - Loss: 0.1304
#   Batch 27/49 - Loss: 0.1284
#   Batch 28/49 - Loss: 0.1235
#   Batch 29/49 - Loss: 0.1276
#   Batch 30/49 - Loss: 0.1411
#   Batch 31/49 - Loss: 0.1557
#   Batch 32/49 - Loss: 0.1442
#   Batch 33/49 - Loss: 0.1403
#   Batch 34/49 - Loss: 0.1493
#   Batch 35/49 - Loss: 0.1142
#   Batch 36/49 - Loss: 0.1379
#   Batch 37/49 - Loss: 0.1367
#   Batch 38/49 - Loss: 0.1505
#   Batch 39/49 - Loss: 0.1256
#   Batch 40/49 - Loss: 0.1150
#   Batch 41/49 - Loss: 0.1457
#   Batch 42/49 - Loss: 0.1649
#   Batch 43/49 - Loss: 0.1217
#   Batch 44/49 - Loss: 0.1132
#   Batch 45/49 - Loss: 0.1416
#   Batch 46/49 - Loss: 0.1307
#   Batch 47/49 - Loss: 0.1337
#   Batch 48/49 - Loss: 0.1171
#   Batch 49/49 - Loss: 0.1176
# Epoch 217 Completed ✅ | Train Loss: 0.1317 | Val Loss: 0.2894
#
# Epoch 218/1000
#   Batch 1/49 - Loss: 0.1228
#   Batch 2/49 - Loss: 0.1288
#   Batch 3/49 - Loss: 0.1189
#   Batch 4/49 - Loss: 0.1217
#   Batch 5/49 - Loss: 0.1358
#   Batch 6/49 - Loss: 0.1272
#   Batch 7/49 - Loss: 0.1339
#   Batch 8/49 - Loss: 0.1166
#   Batch 9/49 - Loss: 0.1217
#   Batch 10/49 - Loss: 0.1404
#   Batch 11/49 - Loss: 0.1390
#   Batch 12/49 - Loss: 0.1345
#   Batch 13/49 - Loss: 0.1374
#   Batch 14/49 - Loss: 0.1425
#   Batch 15/49 - Loss: 0.1319
#   Batch 16/49 - Loss: 0.1495
#   Batch 17/49 - Loss: 0.1427
#   Batch 18/49 - Loss: 0.1204
#   Batch 19/49 - Loss: 0.1389
#   Batch 20/49 - Loss: 0.1347
#   Batch 21/49 - Loss: 0.1277
#   Batch 22/49 - Loss: 0.1359
#   Batch 23/49 - Loss: 0.1444
#   Batch 24/49 - Loss: 0.1254
#   Batch 25/49 - Loss: 0.1274
#   Batch 26/49 - Loss: 0.1446
#   Batch 27/49 - Loss: 0.1267
#   Batch 28/49 - Loss: 0.1474
#   Batch 29/49 - Loss: 0.1245
#   Batch 30/49 - Loss: 0.1242
#   Batch 31/49 - Loss: 0.1278
#   Batch 32/49 - Loss: 0.1466
#   Batch 33/49 - Loss: 0.1390
#   Batch 34/49 - Loss: 0.1267
#   Batch 35/49 - Loss: 0.1330
#   Batch 36/49 - Loss: 0.1180
#   Batch 37/49 - Loss: 0.1102
#   Batch 38/49 - Loss: 0.1323
#   Batch 39/49 - Loss: 0.1555
#   Batch 40/49 - Loss: 0.1452
#   Batch 41/49 - Loss: 0.1160
#   Batch 42/49 - Loss: 0.1388
#   Batch 43/49 - Loss: 0.1259
#   Batch 44/49 - Loss: 0.1221
#   Batch 45/49 - Loss: 0.1229
#   Batch 46/49 - Loss: 0.1284
#   Batch 47/49 - Loss: 0.1418
#   Batch 48/49 - Loss: 0.1141
#   Batch 49/49 - Loss: 0.1652
# Epoch 218 Completed ✅ | Train Loss: 0.1322 | Val Loss: 0.2961
#
# Epoch 219/1000
#   Batch 1/49 - Loss: 0.1373
#   Batch 2/49 - Loss: 0.1398
#   Batch 3/49 - Loss: 0.1340
#   Batch 4/49 - Loss: 0.1315
#   Batch 5/49 - Loss: 0.1337
#   Batch 6/49 - Loss: 0.1204
#   Batch 7/49 - Loss: 0.1357
#   Batch 8/49 - Loss: 0.1354
#   Batch 9/49 - Loss: 0.1379
#   Batch 10/49 - Loss: 0.1317
#   Batch 11/49 - Loss: 0.1298
#   Batch 12/49 - Loss: 0.1229
#   Batch 13/49 - Loss: 0.1485
#   Batch 14/49 - Loss: 0.1511
#   Batch 15/49 - Loss: 0.1263
#   Batch 16/49 - Loss: 0.1265
#   Batch 17/49 - Loss: 0.1404
#   Batch 18/49 - Loss: 0.1287
#   Batch 19/49 - Loss: 0.1314
#   Batch 20/49 - Loss: 0.1250
#   Batch 21/49 - Loss: 0.1330
#   Batch 22/49 - Loss: 0.1283
#   Batch 23/49 - Loss: 0.1226
#   Batch 24/49 - Loss: 0.1583
#   Batch 25/49 - Loss: 0.1274
#   Batch 26/49 - Loss: 0.1452
#   Batch 27/49 - Loss: 0.1174
#   Batch 28/49 - Loss: 0.1419
#   Batch 29/49 - Loss: 0.1300
#   Batch 30/49 - Loss: 0.1557
#   Batch 31/49 - Loss: 0.1497
#   Batch 32/49 - Loss: 0.1141
#   Batch 33/49 - Loss: 0.1229
#   Batch 34/49 - Loss: 0.1292
#   Batch 35/49 - Loss: 0.1350
#   Batch 36/49 - Loss: 0.1385
#   Batch 37/49 - Loss: 0.1341
#   Batch 38/49 - Loss: 0.1060
#   Batch 39/49 - Loss: 0.1283
#   Batch 40/49 - Loss: 0.1321
#   Batch 41/49 - Loss: 0.1229
#   Batch 42/49 - Loss: 0.1136
#   Batch 43/49 - Loss: 0.1304
#   Batch 44/49 - Loss: 0.1285
#   Batch 45/49 - Loss: 0.1380
#   Batch 46/49 - Loss: 0.1304
#   Batch 47/49 - Loss: 0.1213
#   Batch 48/49 - Loss: 0.1321
#   Batch 49/49 - Loss: 0.1409
# Epoch 219 Completed ✅ | Train Loss: 0.1322 | Val Loss: 0.3007
#
# Epoch 220/1000
#   Batch 1/49 - Loss: 0.1540
#   Batch 2/49 - Loss: 0.1262
#   Batch 3/49 - Loss: 0.1198
#   Batch 4/49 - Loss: 0.1332
#   Batch 5/49 - Loss: 0.1395
#   Batch 6/49 - Loss: 0.1331
#   Batch 7/49 - Loss: 0.1508
#   Batch 8/49 - Loss: 0.1441
#   Batch 9/49 - Loss: 0.1271
#   Batch 10/49 - Loss: 0.1169
#   Batch 11/49 - Loss: 0.1365
#   Batch 12/49 - Loss: 0.1241
#   Batch 13/49 - Loss: 0.1108
#   Batch 14/49 - Loss: 0.1435
#   Batch 15/49 - Loss: 0.1230
#   Batch 16/49 - Loss: 0.1377
#   Batch 17/49 - Loss: 0.1247
#   Batch 18/49 - Loss: 0.1239
#   Batch 19/49 - Loss: 0.1165
#   Batch 20/49 - Loss: 0.1203
#   Batch 21/49 - Loss: 0.1308
#   Batch 22/49 - Loss: 0.1437
#   Batch 23/49 - Loss: 0.1439
#   Batch 24/49 - Loss: 0.1077
#   Batch 25/49 - Loss: 0.1590
#   Batch 26/49 - Loss: 0.1330
#   Batch 27/49 - Loss: 0.1493
#   Batch 28/49 - Loss: 0.1285
#   Batch 29/49 - Loss: 0.1219
#   Batch 30/49 - Loss: 0.1090
#   Batch 31/49 - Loss: 0.1373
#   Batch 32/49 - Loss: 0.1268
#   Batch 33/49 - Loss: 0.1368
#   Batch 34/49 - Loss: 0.1059
#   Batch 35/49 - Loss: 0.1372
#   Batch 36/49 - Loss: 0.1156
#   Batch 37/49 - Loss: 0.1227
#   Batch 38/49 - Loss: 0.1199
#   Batch 39/49 - Loss: 0.1027
#   Batch 40/49 - Loss: 0.1486
#   Batch 41/49 - Loss: 0.1230
#   Batch 42/49 - Loss: 0.1184
#   Batch 43/49 - Loss: 0.1376
#   Batch 44/49 - Loss: 0.1244
#   Batch 45/49 - Loss: 0.1542
#   Batch 46/49 - Loss: 0.1573
#   Batch 47/49 - Loss: 0.1103
#   Batch 48/49 - Loss: 0.1233
#   Batch 49/49 - Loss: 0.1203
# Epoch 220 Completed ✅ | Train Loss: 0.1297 | Val Loss: 0.3016
#
# Epoch 221/1000
#   Batch 1/49 - Loss: 0.1471
#   Batch 2/49 - Loss: 0.1247
#   Batch 3/49 - Loss: 0.1157
#   Batch 4/49 - Loss: 0.1177
#   Batch 5/49 - Loss: 0.1360
#   Batch 6/49 - Loss: 0.1406
#   Batch 7/49 - Loss: 0.1295
#   Batch 8/49 - Loss: 0.1249
#   Batch 9/49 - Loss: 0.1283
#   Batch 10/49 - Loss: 0.1430
#   Batch 11/49 - Loss: 0.1552
#   Batch 12/49 - Loss: 0.1316
#   Batch 13/49 - Loss: 0.1377
#   Batch 14/49 - Loss: 0.1285
#   Batch 15/49 - Loss: 0.1242
#   Batch 16/49 - Loss: 0.1321
#   Batch 17/49 - Loss: 0.1496
#   Batch 18/49 - Loss: 0.1203
#   Batch 19/49 - Loss: 0.1437
#   Batch 20/49 - Loss: 0.1363
#   Batch 21/49 - Loss: 0.1172
#   Batch 22/49 - Loss: 0.1288
#   Batch 23/49 - Loss: 0.1573
#   Batch 24/49 - Loss: 0.1036
#   Batch 25/49 - Loss: 0.1177
#   Batch 26/49 - Loss: 0.1216
#   Batch 27/49 - Loss: 0.1150
#   Batch 28/49 - Loss: 0.1426
#   Batch 29/49 - Loss: 0.1373
#   Batch 30/49 - Loss: 0.1346
#   Batch 31/49 - Loss: 0.1213
#   Batch 32/49 - Loss: 0.1403
#   Batch 33/49 - Loss: 0.1430
#   Batch 34/49 - Loss: 0.1267
#   Batch 35/49 - Loss: 0.1373
#   Batch 36/49 - Loss: 0.1016
#   Batch 37/49 - Loss: 0.1301
#   Batch 38/49 - Loss: 0.1250
#   Batch 39/49 - Loss: 0.1275
#   Batch 40/49 - Loss: 0.1380
#   Batch 41/49 - Loss: 0.1398
#   Batch 42/49 - Loss: 0.1477
#   Batch 43/49 - Loss: 0.1269
#   Batch 44/49 - Loss: 0.1266
#   Batch 45/49 - Loss: 0.1249
#   Batch 46/49 - Loss: 0.1332
#   Batch 47/49 - Loss: 0.1371
#   Batch 48/49 - Loss: 0.1224
#   Batch 49/49 - Loss: 0.1486
# Epoch 221 Completed ✅ | Train Loss: 0.1314 | Val Loss: 0.2912
#
# Epoch 222/1000
#   Batch 1/49 - Loss: 0.1352
#   Batch 2/49 - Loss: 0.1460
#   Batch 3/49 - Loss: 0.1169
#   Batch 4/49 - Loss: 0.1458
#   Batch 5/49 - Loss: 0.1077
#   Batch 6/49 - Loss: 0.1275
#   Batch 7/49 - Loss: 0.1401
#   Batch 8/49 - Loss: 0.1204
#   Batch 9/49 - Loss: 0.1238
#   Batch 10/49 - Loss: 0.1228
#   Batch 11/49 - Loss: 0.1423
#   Batch 12/49 - Loss: 0.1228
#   Batch 13/49 - Loss: 0.1221
#   Batch 14/49 - Loss: 0.1032
#   Batch 15/49 - Loss: 0.1198
#   Batch 16/49 - Loss: 0.1148
#   Batch 17/49 - Loss: 0.1186
#   Batch 18/49 - Loss: 0.1095
#   Batch 19/49 - Loss: 0.1346
#   Batch 20/49 - Loss: 0.1509
#   Batch 21/49 - Loss: 0.1266
#   Batch 22/49 - Loss: 0.1415
#   Batch 23/49 - Loss: 0.1451
#   Batch 24/49 - Loss: 0.1387
#   Batch 25/49 - Loss: 0.1352
#   Batch 26/49 - Loss: 0.1204
#   Batch 27/49 - Loss: 0.1300
#   Batch 28/49 - Loss: 0.1405
#   Batch 29/49 - Loss: 0.1421
#   Batch 30/49 - Loss: 0.1105
#   Batch 31/49 - Loss: 0.1281
#   Batch 32/49 - Loss: 0.1056
#   Batch 33/49 - Loss: 0.1348
#   Batch 34/49 - Loss: 0.1156
#   Batch 35/49 - Loss: 0.1167
#   Batch 36/49 - Loss: 0.1291
#   Batch 37/49 - Loss: 0.1375
#   Batch 38/49 - Loss: 0.1528
#   Batch 39/49 - Loss: 0.1465
#   Batch 40/49 - Loss: 0.1186
#   Batch 41/49 - Loss: 0.1380
#   Batch 42/49 - Loss: 0.1294
#   Batch 43/49 - Loss: 0.1235
#   Batch 44/49 - Loss: 0.1238
#   Batch 45/49 - Loss: 0.1268
#   Batch 46/49 - Loss: 0.1320
#   Batch 47/49 - Loss: 0.1728
#   Batch 48/49 - Loss: 0.1153
#   Batch 49/49 - Loss: 0.1049
# Epoch 222 Completed ✅ | Train Loss: 0.1287 | Val Loss: 0.2937
#
# Epoch 223/1000
#   Batch 1/49 - Loss: 0.1272
#   Batch 2/49 - Loss: 0.1116
#   Batch 3/49 - Loss: 0.1310
#   Batch 4/49 - Loss: 0.1581
#   Batch 5/49 - Loss: 0.1450
#   Batch 6/49 - Loss: 0.1066
#   Batch 7/49 - Loss: 0.1233
#   Batch 8/49 - Loss: 0.1136
#   Batch 9/49 - Loss: 0.1215
#   Batch 10/49 - Loss: 0.1307
#   Batch 11/49 - Loss: 0.1125
#   Batch 12/49 - Loss: 0.1013
#   Batch 13/49 - Loss: 0.1420
#   Batch 14/49 - Loss: 0.1462
#   Batch 15/49 - Loss: 0.1325
#   Batch 16/49 - Loss: 0.1323
#   Batch 17/49 - Loss: 0.1091
#   Batch 18/49 - Loss: 0.1265
#   Batch 19/49 - Loss: 0.1063
#   Batch 20/49 - Loss: 0.1418
#   Batch 21/49 - Loss: 0.1255
#   Batch 22/49 - Loss: 0.1095
#   Batch 23/49 - Loss: 0.1506
#   Batch 24/49 - Loss: 0.1291
#   Batch 25/49 - Loss: 0.1284
#   Batch 26/49 - Loss: 0.1453
#   Batch 27/49 - Loss: 0.1350
#   Batch 28/49 - Loss: 0.1277
#   Batch 29/49 - Loss: 0.1267
#   Batch 30/49 - Loss: 0.1391
#   Batch 31/49 - Loss: 0.1245
#   Batch 32/49 - Loss: 0.1463
#   Batch 33/49 - Loss: 0.1372
#   Batch 34/49 - Loss: 0.1113
#   Batch 35/49 - Loss: 0.1393
#   Batch 36/49 - Loss: 0.1296
#   Batch 37/49 - Loss: 0.1459
#   Batch 38/49 - Loss: 0.1539
#   Batch 39/49 - Loss: 0.1241
#   Batch 40/49 - Loss: 0.1245
#   Batch 41/49 - Loss: 0.1414
#   Batch 42/49 - Loss: 0.1213
#   Batch 43/49 - Loss: 0.1325
#   Batch 44/49 - Loss: 0.1132
#   Batch 45/49 - Loss: 0.1401
#   Batch 46/49 - Loss: 0.1292
#   Batch 47/49 - Loss: 0.1475
#   Batch 48/49 - Loss: 0.1226
#   Batch 49/49 - Loss: 0.1264
# Epoch 223 Completed ✅ | Train Loss: 0.1295 | Val Loss: 0.2971
# 🛑 Early stopping at epoch 223

# %% [markdown]
# # Plotting the loss function
# - Download the training loss and Val loss using tensorboard

# %%
train_loss = pd.read_csv("train_loss.csv")
val_loss = pd.read_csv("val_loss.csv")

plt.figure(figsize=(10, 5))
plt.plot(train_loss['epoch'], train_loss['loss'], label='Train Loss')
plt.plot(val_loss['epoch'], val_loss['loss'], label='Val Loss')
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training and Validation Loss")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Evaluation

# %%
model.eval()
test_dice = 0
with torch.no_grad():
    for img, msk in test_dl:
        img, msk = img.to(device), msk.to(device)
        pred = model(img)
        test_dice += 1 - dice_loss(pred, msk).item()

print(f"Average Dice Coefficient on test dataset = {test_dice / len(test_dl):.4f}")
# Out:
# Average Dice Coefficient on test dataset = 0.7184
